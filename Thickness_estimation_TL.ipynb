# %% [markdown]
# # Thickness estimation for pCO2 Silicone layer NN

# %%
#To use on GPU
import tensorflow as tf
#from tensorflow.python.client import device_lib
print("Num GPUs Available: " , len(tf.config.experimental.list_physical_devices('GPU')))
tf.config.experimental.list_physical_devices('GPU')
# Out:
# Num GPUs Available:  1
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Import

# Imported from other script(Classification model)
import os

import matplotlib as mpl
import matplotlib.pyplot as plt
from IPython.display import display

from skimage import data, color
from skimage.transform import rescale, resize, downscale_local_mean
import pandas as pd
import numpy as np
import math
#import imblearn
#import cv2 as cv

import imageio

from PIL import Image
import PIL

from sklearn import decomposition
from sklearn.preprocessing import StandardScaler

from skimage.feature import hog
from skimage.color import rgb2grey
from skimage.io import imread
from skimage.io import imsave
from skimage import color
from skimage.transform import hough_circle
from skimage.transform import hough_ellipse, hough_circle_peaks
from skimage.feature import canny
from skimage.draw import circle_perimeter
from skimage.util import img_as_ubyte
from skimage.filters import threshold_otsu
from skimage import img_as_ubyte


from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.svm import SVC
from sklearn import decomposition
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import roc_curve, auc
#from sklearn.metrics import plot_confusion_matrix


from keras.preprocessing.image import ImageDataGenerator
#from imblearn.over_sampling import SMOTE

	
from datetime import datetime



#Plotting parameters
#plt.style.use('ggplot')
# %matplotlib inline
#import seaborn as sns
#sns.set()
plt.rcParams['figure.figsize'] = (16, 8)
plt.rcParams["axes.grid"] = False
# Out:
# Using TensorFlow backend.

# %% [markdown]
# Lets take a look on the data

# %%
labels = pd.read_excel("C:/Users/Bruger/Desktop/MasterThesis/initial_set/4/thickness_estimation.xlsx", index_col= "Image ID")
labels = labels.drop(["Old Name","OK", "array_ID_board", "Array_ID_run"], axis = 1) 
#labels.drop(labels.tail(n).index,inplace=True) # drop last n rows
labels = labels.dropna()
labels.head(7)
# Out:
#                                     New Name  \
# Image ID
# 0         932-028R10929N001_Array=01_001.png
# 1         932-028R10929N001_Array=01_002.png
# 2         932-028R10929N001_Array=01_003.png
# 3         932-028R10929N001_Array=01_004.png
# 4         932-028R10929N001_Array=01_005.png
# 5         932-028R10929N001_Array=01_006.png
# 6         932-028R10929N001_Array=02_001.png
#
#                                                        Path  Band  Sensor_ID  \
# Image ID
# 0         C:\Users\Bruger\Desktop\MasterThesis\initial_s...     1          0
# 1         C:\Users\Bruger\Desktop\MasterThesis\initial_s...     2          0
# 2         C:\Users\Bruger\Desktop\MasterThesis\initial_s...     3          0
# 3         C:\Users\Bruger\Desktop\MasterThesis\initial_s...     4          0
# 4         C:\Users\Bruger\Desktop\MasterThesis\initial_s...     5          0
# 5         C:\Users\Bruger\Desktop\MasterThesis\initial_s...     6          0
# 6         C:\Users\Bruger\Desktop\MasterThesis\initial_s...     1          1
#
#           Label  Thickness
# Image ID
# 0             1     56.912
# 1             1     56.912
# 2             1     56.912
# 3             1     56.912
# 4             1     56.912
# 5             1     56.912
# 6             1     51.620

# %% [markdown]
# First, there are some values in the 3D scanning, noted as errors since the scanning of these sensors were lacking in some way or another. Lets remove them from this data.

# %%
#Labels prior to removal
labels.describe()
# Out:
#               Band    Sensor_ID   Label    Thickness
# count  9984.000000  9984.000000  9984.0  9984.000000
# mean      3.500000   831.500000     1.0    51.212919
# std       1.707911   480.379395     0.0     7.643830
# min       1.000000     0.000000     1.0     0.000000
# 25%       2.000000   415.750000     1.0    49.073750
# 50%       3.500000   831.500000     1.0    52.039000
# 75%       5.000000  1247.250000     1.0    54.520250
# max       6.000000  1663.000000     1.0    83.148000

# %%
labels.dtypes
# Out:
# New Name      object
# Path          object
# Band           int64
# Sensor_ID      int64
# Label          int64
# Thickness    float64
# dtype: object

# %% [markdown]
# Lets remove everything below 20 in thickness from the dataframe. This is the lower limit for acceptaple thickness.

# %%
print('df before drop', labels.shape)
# = labels.replace(np.nan , 0)
labels.drop(labels[labels.Thickness < 20].index, inplace=True)
print('df after drop thickness <20', labels.shape)
labels.dropna()
print('df after drop N/A values', labels.shape)
#labels.describe()
# Out:
# df before drop (9984, 6)
# df after drop thickness <20 (9936, 6)
# df after drop N/A values (9936, 6)

# %%
mu = labels["Thickness"].mean()
sigma = labels["Thickness"].std()
s = labels["Thickness"]
count, bins, ignored = plt.hist(s, 30, density=True)
plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) * np.exp( - (bins - mu)**2 / (2 * sigma**2) ), linewidth=2, color='r')
plt.rcParams["figure.figsize"] = (10, 5)
plt.title("Distribution of silicone layer thickness")
plt.show()

# %% [markdown]
# ## Functions

# %%
def get_path_and_image_name(df, Image_ID):
    filename = df.iloc[Image_ID, 0]
    path = df.iloc[Image_ID, 1]
    file_path = os.path.join(path, filename)
    #img = cv.imread('filepath',0)
    img=Image.open(file_path)
    #img = resize(img, (1750, 1750), anti_aliasing=True)
    return np.array(img)

# %%
def get_image_in_pil(df, Image_ID):
    filename = df.iloc[Image_ID, 0]
    path = df.iloc[Image_ID, 1]
    file_path = os.path.join(path, filename)
    
    image = Image.open(file_path) 
    #image.load()
    return image

# %%
def get_image_in_pil_resize(df, Image_ID, size):
    #Assuming quadratic resize
    filename = df.iloc[Image_ID, 0]
    path = df.iloc[Image_ID, 1]
    file_path = os.path.join(path, filename)
    
    image = Image.open(file_path) 
    image = image.resize((size, size))
    #image.load()
    return image

# %%
def get_path_and_image_name_resized(df, Image_ID, size):
    filename = df.iloc[Image_ID, 0]
    path = df.iloc[Image_ID, 1]
    file_path = os.path.join(path, filename)
    #img = cv.imread('filepath',0)
    img = imread(file_path)
    img = resize(img, (size, size), anti_aliasing=True)
    return np.array(img)

# %%
def get_file_path(df, Image_ID):
    filename = df.iloc[Image_ID, 0]
    path = df.iloc[Image_ID, 1]
    file_path = os.path.join(path, filename)
    return file_path

# %%
#A image of one of the discarded sensors
plt.figure(figsize=(15, 11))
temp = 6*12
image = imread(get_file_path(labels,temp+5), as_gray=True)

image = resize(image, (500, 500), anti_aliasing=True)

plt.figure(figsize=(7, 5))
plt.imshow(image, cmap='gray')
#plt.title("Approved sensor, silicone")
plt.axis('off')
#plt.savefig('IMG_test')
plt.show()

# %%
def create_rgb_custom(df, img_id, mode = 'cox'):
    
    if mode == 'cox':
        r = get_path_and_image_name(df, img_id)
        g = get_path_and_image_name(df, img_id+1)
        b = get_path_and_image_name(df, img_id+2)
        
        rgb = np.dstack((r, g, b))
    if mode == 'dark':
        r = get_path_and_image_name(df, img_id+3)
        g = get_path_and_image_name(df, img_id+4)
        b = get_path_and_image_name(df, img_id+5)
        
        rgb = np.dstack((r, g, b))
    
    if mode == 'both':
        r1 = get_path_and_image_name(df, img_id)
        g1 = get_path_and_image_name(df, img_id+1)
        b1 = get_path_and_image_name(df, img_id+2)
        r2 = get_path_and_image_name(df, img_id+3)
        g2 = get_path_and_image_name(df, img_id+4)
        b2 = get_path_and_image_name(df, img_id+5)
        rgb = np.dstack((r1, g1, b1, r2, g2, b2))
        
    if mode == 'avg':
        r1 = get_path_and_image_name(df, img_id)
        g1 = get_path_and_image_name(df, img_id+1)
        b1 = get_path_and_image_name(df, img_id+2)
        r2 = get_path_and_image_name(df, img_id+3)
        g2 = get_path_and_image_name(df, img_id+4)
        b2 = get_path_and_image_name(df, img_id+5)
        
#         r = (r1+r2)/2
#         g = (g1+g2)/2
        #b = (b1+b2)/2
        r = ((np.array(r1)+np.array(r2))/2)
        g = ((np.array(g1)+np.array(g2))/2)
        b = ((np.array(b1)+np.array(b2))/2)
        
        rgb = np.dstack((r, g, b))
        rgb = np.round(rgb)
        rgb = rgb.astype(int)
        
#     mask = get_crop_mask(img_id+2)
#     rgb = crop_image2(rgb, mask)
    #if scale = True:
        
    #rgb = resize(rgb, (size, size), anti_aliasing=True)     
    return rgb
        
        
        
    
        
        
image = create_rgb_custom(labels, 60,  mode='cox')
#print('image shape,' image.shape())
#image = resize(image, (500, 500))
img_max=image.max()
img_min=image.min()
img_mean=image.mean()
img_std=image.std()

print('max', img_max)
print('min', img_min)
print('mean', img_mean)
print('std', img_std)
# Out:
# max 255
# min 0
# mean 56.6482976651351
# std 38.29957638608166

# %%
#A image of one of the discarded sensors
plt.figure(figsize=(15, 11))

image = create_rgb_custom(labels, 60, mode ='cox')
#mask  = get_crop_mask(60+2)
#image = crop_image2(image, mask)
#image = resize(image, (500, 500), anti_aliasing=True)

plt.figure(figsize=(7, 5))
plt.imshow(image)
#plt.title("Approved sensor, silicone")
plt.axis('off')
#plt.savefig('IMG_test')
plt.show()

# %% [markdown]
# ## Cropping

# %%
for img_id in range(6):
    image = get_path_and_image_name(labels, (60)+img_id) #300 - tush marker, #54 - total smushed sensor,
    image = resize(image, (400, 400), anti_aliasing=True)

    thresh = threshold_otsu(image)
    binary = image > thresh

    fig, axes = plt.subplots(ncols=3, nrows=6, figsize=(16, 5))
    ax = axes.ravel()
    ax[0] = plt.subplot(1, 3, 1)
    ax[1] = plt.subplot(1, 3, 2)
    ax[2] = plt.subplot(1, 3, 3, sharex=ax[0], sharey=ax[0])

    ax[0].imshow(image, cmap=plt.cm.gray)
    ax[0].set_title('Original')
    ax[0].axis('off')

    ax[1].hist(image.ravel(), bins=256)
    ax[1].set_title('Histogram')
    ax[1].axvline(thresh, color='r')

    ax[2].imshow(binary, cmap=plt.cm.gray)
    ax[2].set_title('Thresholded')
    ax[2].axis('off')
    plt.show()

# %%
def crop_image(img_id, tol=0): # not used
    
    image = get_path_and_image_name(labels, img_id)
    #image = resize(image, (400, 400), anti_aliasing=True)

    thresh = threshold_otsu(image)
    binary = image > thresh
    # img is 2D image data
    # tol  is tolerance
    mask = binary>tol
    #print('mask', mask)
    return image[np.ix_(mask.any(1),mask.any(0))]
    #return mask

# %%
def get_crop_mask(img_id, tol=0):
    
    image = get_path_and_image_name(labels, img_id)
    #image = resize(image, (400, 400), anti_aliasing=True)

    thresh = threshold_otsu(image)
    binary = image > thresh
    # img is 2D image data
    # tol  is tolerance
    mask = binary>tol
    #print('mask1', mask)
    #return image[np.ix_(mask.any(1),mask.any(0))]
    return mask

# %%
def crop_image2(img_id, Mask, tol=0):
    
    image = get_path_and_image_name(labels, img_id)
    mask = Mask
    #print('mask2', mask)
    return image[np.ix_(mask.any(1),mask.any(0))]
    #return mask

# %%
def crop_image3(image, Mask, tol=0):
    
    mask = Mask
    #print('mask2', mask)
    return image[np.ix_(mask.any(1),mask.any(0))]
    #return mask

# %%
def get_shape_in_mm(image):
    res = 0.0021
    print('width:', image.shape[0]*res)
    print('length:', image.shape[1]*res)

# %%
#A image of one of the discarded sensors
plt.figure(figsize=(15, 11))

image = create_rgb_custom(labels, 60, mode ='cox')
print('uncropped image shape', image.shape)
print('height/width ratio', image.shape[0]/image.shape[0])
mask  = get_crop_mask(60+2)
image = crop_image3(image, mask)
print('cropped image shape', image.shape)
print('height/width ratio', image.shape[0]/image.shape[1])
HW_ratio = image.shape[0]/image.shape[1] 
image_size_width = 112
image_size_height = int(np.round((image_size_width * HW_ratio)))
print('height', image_size_height)

image = resize(image, (image_size_height, image_size_width), anti_aliasing=True)



plt.figure(figsize=(10,10))
plt.imshow(image)
#plt.title("Approved sensor, silicone")
plt.axis('off')
#plt.savefig('IMG_test')
plt.show()
# Out:
# uncropped image shape (1921, 2051, 3)
# height/width ratio 1.0
# cropped image shape (1086, 1629, 3)
# height/width ratio 0.6666666666666666
# height 75

# %% [markdown]
# ## NN preprocess

# %%
image_list_arr = []
size_images = 224
for img_id in range(len(labels)):
#for img_id in range(bug_fix):
    if (img_id % 250) == 0:
        print('Date/Time:', datetime.now(),'-------Image ID:', img_id)
    if labels.iloc[img_id,2] == 1: #if this is the first band, proceed
        image = create_rgb_custom(labels, img_id, mode = 'cox')
        mask  = get_crop_mask(img_id+2)
        image = crop_image3(image, mask)

        image = resize(image, (size_images, size_images), anti_aliasing=True) #estimated empirically
        image = np.array(image, dtype=np.float16)
        image_list_arr.append(image)


image_list_arr = np.array(image_list_arr, dtype=np.float16)
print('image_list length:', len(image_list_arr))
print('Shape of one element:',image_list_arr[1].shape)
print('image_mean', image_list_arr.mean())
print('image_std', image_list_arr.std())
# Out:
# Date/Time: 2020-06-18 20:33:33.127605 -------Image ID: 0
# Date/Time: 2020-06-18 20:33:51.123519 -------Image ID: 250
# Date/Time: 2020-06-18 20:34:09.239993 -------Image ID: 500
# Date/Time: 2020-06-18 20:34:26.467371 -------Image ID: 750
# Date/Time: 2020-06-18 20:34:44.317855 -------Image ID: 1000
# Date/Time: 2020-06-18 20:35:01.746861 -------Image ID: 1250
# Date/Time: 2020-06-18 20:35:19.096025 -------Image ID: 1500
# Date/Time: 2020-06-18 20:35:37.006082 -------Image ID: 1750
# Date/Time: 2020-06-18 20:35:54.497649 -------Image ID: 2000
# Date/Time: 2020-06-18 20:36:11.950867 -------Image ID: 2250
# Date/Time: 2020-06-18 20:36:29.728556 -------Image ID: 2500
# Date/Time: 2020-06-18 20:36:47.307617 -------Image ID: 2750
# Date/Time: 2020-06-18 20:37:05.288150 -------Image ID: 3000
# Date/Time: 2020-06-18 20:37:23.576198 -------Image ID: 3250
# Date/Time: 2020-06-18 20:37:42.109654 -------Image ID: 3500
# Date/Time: 2020-06-18 20:38:00.522671 -------Image ID: 3750
# Date/Time: 2020-06-18 20:38:19.816519 -------Image ID: 4000
# Date/Time: 2020-06-18 20:38:38.278830 -------Image ID: 4250
# Date/Time: 2020-06-18 20:38:56.173478 -------Image ID: 4500
# Date/Time: 2020-06-18 20:39:14.694208 -------Image ID: 4750
# Date/Time: 2020-06-18 20:39:33.015728 -------Image ID: 5000
# Date/Time: 2020-06-18 20:39:50.922454 -------Image ID: 5250
# Date/Time: 2020-06-18 20:40:08.927183 -------Image ID: 5500
# Date/Time: 2020-06-18 20:40:27.268261 -------Image ID: 5750
# Date/Time: 2020-06-18 20:40:44.954833 -------Image ID: 6000
# Date/Time: 2020-06-18 20:41:03.902268 -------Image ID: 6250
# Date/Time: 2020-06-18 20:41:22.729408 -------Image ID: 6500
# Date/Time: 2020-06-18 20:41:40.615606 -------Image ID: 6750
# Date/Time: 2020-06-18 20:41:59.141747 -------Image ID: 7000
# Date/Time: 2020-06-18 20:42:17.214915 -------Image ID: 7250
# Date/Time: 2020-06-18 20:42:35.352829 -------Image ID: 7500
# Date/Time: 2020-06-18 20:42:53.675331 -------Image ID: 7750
# Date/Time: 2020-06-18 20:43:12.053399 -------Image ID: 8000
# Date/Time: 2020-06-18 20:43:30.496551 -------Image ID: 8250
# Date/Time: 2020-06-18 20:43:48.708898 -------Image ID: 8500
# Date/Time: 2020-06-18 20:44:07.405539 -------Image ID: 8750
# Date/Time: 2020-06-18 20:44:25.467132 -------Image ID: 9000
# Date/Time: 2020-06-18 20:44:43.665023 -------Image ID: 9250
# Date/Time: 2020-06-18 20:45:02.104579 -------Image ID: 9500
# Date/Time: 2020-06-18 20:45:20.175901 -------Image ID: 9750
# image_list length: 1656
# Shape of one element: (224, 224, 3)
# image_mean 0.3027
# C:\Users\Bruger\Anaconda3\envs\TFGPU\lib\site-packages\numpy\core\_methods.py:183: RuntimeWarning: overflow encountered in reduce
#   arrmean = umr_sum(arr, axis, dtype, keepdims=True)
# image_std inf

# %%
image_list_arr = np.array(image_list_arr, dtype=np.float16)

print('image_list length:', len(image_list_arr))
print('Shape of one element:',image_list_arr[1].shape)
print('image_mean', image_list_arr.mean())
print('image_std', image_list_arr.std())
print('image_max', image_list_arr.max())
print('image_min', image_list_arr.min())
# Out:
# image_list length: 1656
# Shape of one element: (224, 224, 3)
# image_mean 0.3027
# image_std inf
# image_max 0.996
# image_min 0.00392

# %%
#Dropping all images that is not the first band(we represent one sensor only one time)
labels_df = labels[labels.Band ==1]
#set index to sensor ID
labels_df = labels_df.set_index('Sensor_ID')
#dropping information that is not needed.
labels_df = labels_df.drop(["Band", "Label"], axis = 1)

#Define x and y... x is actually not used
X_df = labels_df.drop(["Thickness"], axis=1)
y_df = labels_df.drop(["New Name", "Path"], axis=1)


y_max = y_df.max()
y_min = y_df.min()
y_mean = y_df.mean()
y_std = y_df.std()
y_df = y_df/y_max
y_df = y_df.to_numpy()
y_df = np.array(y_df)
print('y_max',y_max)
print('y_min',y_min)
print('y_mean', y_mean)
print('y_std', y_std)
# Out:
# y_max Thickness    83.148
# dtype: float64
# y_min Thickness    24.812
# dtype: float64
# y_mean Thickness    51.458467
# dtype: float64
# y_std Thickness    6.796202
# dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(image_list_arr, y_df, test_size=0.20, random_state=42)

X_test, X_val, y_test, y_val = train_test_split(X_test, y_test, test_size=0.5, random_state=42) # 0.25 x 0.8 = 0.2
print('shape of X_train', X_train.shape)
print('shape of y_train', y_train.shape)
print('---------------------------')
print('shape of X_test', X_test.shape)
print('shape of y_test', y_test.shape)
print('---------------------------')
print('shape of X_val', X_val.shape)
print('Shape of y_val', y_val.shape)
# Out:
# shape of X_train (1324, 224, 224, 3)
# shape of y_train (1324, 1)
# ---------------------------
# shape of X_test (166, 224, 224, 3)
# shape of y_test (166, 1)
# ---------------------------
# shape of X_val (166, 224, 224, 3)
# Shape of y_val (166, 1)

# %% [markdown]
# # Keras Modellos

# %%
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation
from keras.layers.core import Dropout
from keras.layers.core import Dense
from keras.layers import Flatten
from keras.layers import Input
from keras.models import Model
from keras.optimizers import Adam
from keras.optimizers import RMSprop
from keras.optimizers import SGD
from keras import metrics
from keras.preprocessing.image import ImageDataGenerator


from keras.constraints import MinMaxNorm
from sklearn.metrics import r2_score
import math

# custom R2-score metrics for keras backend
from keras import backend as K

# %%
print('Queue eye of the tiger, its training time!')
print(' Dum, dum dum dum, dum dum duuuuuum, Dum, dum dum dum, dum dum duuuuuum ')
print('Training started at:----------', datetime.now())
# Out:
# Queue eye of the tiger, its training time!
#  Dum, dum dum dum, dum dum duuuuuum, Dum, dum dum dum, dum dum duuuuuum
# Training started at:---------- 2020-06-18 20:45:45.759805

# %%
from keras.applications.vgg16 import VGG16
from keras.applications.inception_v3 import InceptionV3
from keras.applications.resnet50 import ResNet50
from keras.models import Model
from keras.layers import Dense
from keras.layers import Flatten

# %%
model = Sequential()
model.add(ResNet50(weights='imagenet', include_top=False, input_tensor=Input(shape=(224, 224, 3), name='input')))
#model.add(InceptionV3(weights='imagenet', include_top=False, input_tensor=Input(shape=(224, 224, 3), name='input')))
#model.add(VGG16(weights='imagenet', include_top=False, input_tensor=Input(shape=(224, 224, 3), name='input')))
model.add(Flatten(name='flatten'))


#model.add(Dense(500, activation='relu', name='FC1'))
#model.add(Dropout(0.5, name='Drop1'))
#model.add(Dense(500, activation='relu', name='FC2'))
#model.add(Dropout(0.3, name='Drop2'))
model.add(Dense(1, activation='linear', name='predictions'))
# Out:
# C:\Users\Bruger\Anaconda3\envs\TFGPU\lib\site-packages\keras_applications\resnet50.py:265: UserWarning: The output shape of `ResNet50(include_top=False)` has been changed since Keras 2.2.0.
#   warnings.warn('The output shape of `ResNet50(include_top=False)` '

# %%
model.compile(optimizer='RMSprop', loss='mean_squared_error', metrics=(['mse', 'mape', 'mae']))
#generator = image.ImageDataGenerator().flow_from_directory('./data/cifar2tiny-train', target_size=(224, 224), batch_size=4, class_mode='categorical', shuffle=True) #100 images in 2 classes
#model.fit_generator(generator, samples_per_epoch=100, nb_epoch=1)
#model.fit(X_train, y_train, validation_data = (X_val, y_val), epochs=100, batch_size = 8)

# %%
history = model.fit(X_train, y_train, validation_data = (X_val, y_val), epochs=500, batch_size =8)
#history.fit_generator(aug.flow(X_train, y_train, batch_size=8),validation_data=(X_val, y_val),steps_per_epoch=len(X_train) // 8,epochs=50)
# Plot training & validation accuracy values
# Out:
# Train on 1324 samples, validate on 166 samples
# Epoch 1/500
# 1324/1324 [==============================] - 102s 77ms/step - loss: 153.8256 - mse: 153.8257 - mape: 620.1912 - mae: 3.7715 - val_loss: 0.3890 - val_mse: 0.3890 - val_mape: 99.5075 - val_mae: 0.6188
# Epoch 2/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 12.1374 - mse: 12.1374 - mape: 310.0078 - mae: 1.8974 - val_loss: 0.4306 - val_mse: 0.4306 - val_mape: 104.8517 - val_mae: 0.6516
# Epoch 3/500
# 1324/1324 [==============================] - 84s 63ms/step - loss: 6.5614 - mse: 6.5614 - mape: 215.4509 - mae: 1.3261 - val_loss: 0.2341 - val_mse: 0.2341 - val_mape: 75.8117 - val_mae: 0.4756
# Epoch 4/500
# 1324/1324 [==============================] - 84s 63ms/step - loss: 0.4005 - mse: 0.4005 - mape: 65.0766 - mae: 0.3971 - val_loss: 0.1639 - val_mse: 0.1639 - val_mape: 60.0461 - val_mae: 0.3797
# Epoch 5/500
# 1324/1324 [==============================] - 84s 63ms/step - loss: 0.3103 - mse: 0.3103 - mape: 45.0950 - mae: 0.2756 - val_loss: 0.0681 - val_mse: 0.0681 - val_mape: 36.3975 - val_mae: 0.2252
# Epoch 6/500
# 1324/1324 [==============================] - 84s 63ms/step - loss: 0.1591 - mse: 0.1591 - mape: 36.7796 - mae: 0.2224 - val_loss: 0.0076 - val_mse: 0.0076 - val_mape: 10.6181 - val_mae: 0.0653
# Epoch 7/500
# 1324/1324 [==============================] - 84s 63ms/step - loss: 0.1205 - mse: 0.1205 - mape: 35.5934 - mae: 0.2158 - val_loss: 3.6380 - val_mse: 3.6380 - val_mape: 252.6506 - val_mae: 1.4981
# Epoch 8/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 0.0280 - mse: 0.0280 - mape: 20.7627 - mae: 0.1244 - val_loss: 0.0205 - val_mse: 0.0205 - val_mape: 18.7659 - val_mae: 0.1141
# Epoch 9/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 0.0344 - mse: 0.0344 - mape: 19.9161 - mae: 0.1201 - val_loss: 0.0179 - val_mse: 0.0179 - val_mape: 17.6825 - val_mae: 0.1015
# Epoch 10/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 0.0166 - mse: 0.0166 - mape: 14.4969 - mae: 0.0869 - val_loss: 0.0798 - val_mse: 0.0798 - val_mape: 39.1229 - val_mae: 0.2438
# Epoch 11/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 0.0112 - mse: 0.0112 - mape: 12.4797 - mae: 0.0749 - val_loss: 0.0395 - val_mse: 0.0395 - val_mape: 28.1583 - val_mae: 0.1800
# Epoch 12/500
# 1324/1324 [==============================] - 84s 63ms/step - loss: 0.0082 - mse: 0.0082 - mape: 11.3843 - mae: 0.0677 - val_loss: 0.0593 - val_mse: 0.0593 - val_mape: 35.4123 - val_mae: 0.2198
# Epoch 13/500
# 1324/1324 [==============================] - 84s 63ms/step - loss: 0.0062 - mse: 0.0062 - mape: 9.4845 - mae: 0.0568 - val_loss: 0.0075 - val_mse: 0.0075 - val_mape: 12.0140 - val_mae: 0.0756
# Epoch 14/500
# 1324/1324 [==============================] - 84s 63ms/step - loss: 0.0079 - mse: 0.0079 - mape: 10.7703 - mae: 0.0645 - val_loss: 0.0059 - val_mse: 0.0059 - val_mape: 10.6624 - val_mae: 0.0660
# Epoch 15/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 0.0058 - mse: 0.0058 - mape: 9.7493 - mae: 0.0584 - val_loss: 0.0221 - val_mse: 0.0221 - val_mape: 18.5271 - val_mae: 0.1100
# Epoch 16/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 0.0045 - mse: 0.0045 - mape: 8.5213 - mae: 0.0508 - val_loss: 0.0133 - val_mse: 0.0133 - val_mape: 16.3417 - val_mae: 0.1041
# Epoch 17/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 0.0044 - mse: 0.0044 - mape: 8.4720 - mae: 0.0513 - val_loss: 0.0079 - val_mse: 0.0079 - val_mape: 11.6907 - val_mae: 0.0689
# Epoch 18/500
# 1324/1324 [==============================] - 84s 63ms/step - loss: 0.0039 - mse: 0.0039 - mape: 8.0710 - mae: 0.0484 - val_loss: 0.0498 - val_mse: 0.0498 - val_mape: 30.5511 - val_mae: 0.1744
# Epoch 19/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 0.0038 - mse: 0.0038 - mape: 7.9550 - mae: 0.0477 - val_loss: 0.0064 - val_mse: 0.0064 - val_mape: 10.9228 - val_mae: 0.0666
# Epoch 20/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 0.0035 - mse: 0.0035 - mape: 7.7904 - mae: 0.0470 - val_loss: 0.0040 - val_mse: 0.0040 - val_mape: 8.3805 - val_mae: 0.0518
# Epoch 21/500
# 1324/1324 [==============================] - 84s 63ms/step - loss: 0.0031 - mse: 0.0031 - mape: 7.1407 - mae: 0.0431 - val_loss: 0.0062 - val_mse: 0.0062 - val_mape: 10.1230 - val_mae: 0.0579
# Epoch 22/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 0.0033 - mse: 0.0033 - mape: 7.4171 - mae: 0.0447 - val_loss: 0.0070 - val_mse: 0.0070 - val_mape: 12.1258 - val_mae: 0.0704
# Epoch 23/500
# 1324/1324 [==============================] - 85s 64ms/step - loss: 0.0028 - mse: 0.0028 - mape: 6.8666 - mae: 0.0413 - val_loss: 0.0033 - val_mse: 0.0033 - val_mape: 7.1153 - val_mae: 0.0422
# Epoch 24/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 0.0028 - mse: 0.0028 - mape: 6.9572 - mae: 0.0416 - val_loss: 0.0020 - val_mse: 0.0020 - val_mape: 5.6830 - val_mae: 0.0341
# Epoch 25/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 0.0025 - mse: 0.0025 - mape: 6.3805 - mae: 0.0386 - val_loss: 0.0017 - val_mse: 0.0017 - val_mape: 5.1284 - val_mae: 0.0316
# Epoch 26/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 0.0023 - mse: 0.0023 - mape: 6.2935 - mae: 0.0379 - val_loss: 0.0033 - val_mse: 0.0033 - val_mape: 6.9341 - val_mae: 0.0409
# Epoch 27/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 0.0025 - mse: 0.0025 - mape: 6.3817 - mae: 0.0387 - val_loss: 0.0020 - val_mse: 0.0020 - val_mape: 5.8084 - val_mae: 0.0337
# Epoch 28/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 0.0022 - mse: 0.0022 - mape: 5.9971 - mae: 0.0360 - val_loss: 0.0020 - val_mse: 0.0020 - val_mape: 5.6202 - val_mae: 0.0340
# Epoch 29/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 0.0021 - mse: 0.0021 - mape: 5.9616 - mae: 0.0360 - val_loss: 0.0258 - val_mse: 0.0258 - val_mape: 24.6312 - val_mae: 0.1432
# Epoch 30/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 0.0021 - mse: 0.0021 - mape: 5.9163 - mae: 0.0356 - val_loss: 0.0125 - val_mse: 0.0125 - val_mape: 16.2606 - val_mae: 0.1021
# Epoch 31/500
# 1324/1324 [==============================] - 84s 63ms/step - loss: 0.0021 - mse: 0.0021 - mape: 6.0577 - mae: 0.0365 - val_loss: 0.0046 - val_mse: 0.0046 - val_mape: 9.1783 - val_mae: 0.0583
# Epoch 32/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 0.0019 - mse: 0.0019 - mape: 5.7015 - mae: 0.0345 - val_loss: 0.0036 - val_mse: 0.0036 - val_mape: 7.5460 - val_mae: 0.0480
# Epoch 33/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 0.0020 - mse: 0.0020 - mape: 5.8613 - mae: 0.0354 - val_loss: 0.0022 - val_mse: 0.0022 - val_mape: 5.7313 - val_mae: 0.0353
# Epoch 34/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 0.0022 - mse: 0.0022 - mape: 5.9825 - mae: 0.0360 - val_loss: 0.0020 - val_mse: 0.0020 - val_mape: 5.4469 - val_mae: 0.0328
# Epoch 35/500
# 1324/1324 [==============================] - 84s 63ms/step - loss: 0.0024 - mse: 0.0024 - mape: 6.0695 - mae: 0.0365 - val_loss: 0.0015 - val_mse: 0.0015 - val_mape: 4.9595 - val_mae: 0.0299
# Epoch 36/500
# 1324/1324 [==============================] - 84s 63ms/step - loss: 0.0019 - mse: 0.0019 - mape: 5.7279 - mae: 0.0345 - val_loss: 0.0031 - val_mse: 0.0031 - val_mape: 6.5895 - val_mae: 0.0414
# Epoch 37/500
# 1324/1324 [==============================] - 84s 63ms/step - loss: 0.0018 - mse: 0.0018 - mape: 5.6615 - mae: 0.0340 - val_loss: 0.0032 - val_mse: 0.0032 - val_mape: 7.2747 - val_mae: 0.0454
# Epoch 38/500
# 1324/1324 [==============================] - 84s 63ms/step - loss: 0.0018 - mse: 0.0018 - mape: 5.6472 - mae: 0.0338 - val_loss: 0.0050 - val_mse: 0.0050 - val_mape: 9.7810 - val_mae: 0.0565
# Epoch 39/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 0.0017 - mse: 0.0017 - mape: 5.4352 - mae: 0.0326 - val_loss: 0.0024 - val_mse: 0.0024 - val_mape: 6.2902 - val_mae: 0.0372
# Epoch 40/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 0.0018 - mse: 0.0018 - mape: 5.4914 - mae: 0.0330 - val_loss: 0.0132 - val_mse: 0.0132 - val_mape: 18.2264 - val_mae: 0.1088
# Epoch 41/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 0.0017 - mse: 0.0017 - mape: 5.3983 - mae: 0.0325 - val_loss: 0.0058 - val_mse: 0.0058 - val_mape: 10.9900 - val_mae: 0.0668
# Epoch 42/500
# 1324/1324 [==============================] - 84s 63ms/step - loss: 0.0015 - mse: 0.0015 - mape: 5.1169 - mae: 0.0308 - val_loss: 0.0018 - val_mse: 0.0018 - val_mape: 5.2894 - val_mae: 0.0324
# Epoch 43/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 0.0015 - mse: 0.0015 - mape: 5.0942 - mae: 0.0304 - val_loss: 0.0033 - val_mse: 0.0033 - val_mape: 8.0546 - val_mae: 0.0480
# Epoch 44/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 0.0015 - mse: 0.0015 - mape: 5.0103 - mae: 0.0301 - val_loss: 0.0017 - val_mse: 0.0017 - val_mape: 5.3174 - val_mae: 0.0322
# Epoch 45/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 0.0016 - mse: 0.0016 - mape: 5.2000 - mae: 0.0312 - val_loss: 0.0032 - val_mse: 0.0032 - val_mape: 8.0468 - val_mae: 0.0477
# Epoch 46/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 0.0014 - mse: 0.0014 - mape: 4.8183 - mae: 0.0292 - val_loss: 0.0017 - val_mse: 0.0017 - val_mape: 4.9599 - val_mae: 0.0302
# Epoch 47/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 0.0014 - mse: 0.0014 - mape: 4.8068 - mae: 0.0291 - val_loss: 0.0016 - val_mse: 0.0016 - val_mape: 4.7268 - val_mae: 0.0290
# Epoch 48/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 0.0013 - mse: 0.0013 - mape: 4.6470 - mae: 0.0280 - val_loss: 0.0022 - val_mse: 0.0022 - val_mape: 5.2343 - val_mae: 0.0331
# Epoch 49/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 0.0015 - mse: 0.0015 - mape: 5.0327 - mae: 0.0303 - val_loss: 0.0034 - val_mse: 0.0034 - val_mape: 7.4752 - val_mae: 0.0470
# Epoch 50/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 0.0013 - mse: 0.0013 - mape: 4.8060 - mae: 0.0290 - val_loss: 0.0022 - val_mse: 0.0022 - val_mape: 5.7228 - val_mae: 0.0348
# Epoch 51/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 0.0013 - mse: 0.0013 - mape: 4.5967 - mae: 0.0275 - val_loss: 0.0034 - val_mse: 0.0034 - val_mape: 7.2770 - val_mae: 0.0463
# Epoch 52/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 0.0013 - mse: 0.0013 - mape: 4.6524 - mae: 0.0279 - val_loss: 0.0016 - val_mse: 0.0016 - val_mape: 4.7776 - val_mae: 0.0292
# Epoch 53/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 0.0013 - mse: 0.0013 - mape: 4.6263 - mae: 0.0279 - val_loss: 0.0015 - val_mse: 0.0015 - val_mape: 4.5116 - val_mae: 0.0278
# Epoch 54/500
# 1324/1324 [==============================] - 84s 63ms/step - loss: 0.0012 - mse: 0.0012 - mape: 4.6153 - mae: 0.0277 - val_loss: 0.0024 - val_mse: 0.0024 - val_mape: 6.1973 - val_mae: 0.0384
# Epoch 55/500
# 1324/1324 [==============================] - 84s 63ms/step - loss: 0.0012 - mse: 0.0012 - mape: 4.6010 - mae: 0.0275 - val_loss: 0.0021 - val_mse: 0.0021 - val_mape: 5.1914 - val_mae: 0.0325
# Epoch 56/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 0.0012 - mse: 0.0012 - mape: 4.6269 - mae: 0.0279 - val_loss: 0.0110 - val_mse: 0.0110 - val_mape: 15.8544 - val_mae: 0.0971
# Epoch 57/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 0.0012 - mse: 0.0012 - mape: 4.4866 - mae: 0.0269 - val_loss: 0.0057 - val_mse: 0.0057 - val_mape: 10.7811 - val_mae: 0.0644
# Epoch 58/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 0.0012 - mse: 0.0012 - mape: 4.4843 - mae: 0.0269 - val_loss: 0.0023 - val_mse: 0.0023 - val_mape: 6.4009 - val_mae: 0.0398
# Epoch 59/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 0.0011 - mse: 0.0011 - mape: 4.4079 - mae: 0.0265 - val_loss: 0.0036 - val_mse: 0.0036 - val_mape: 8.5871 - val_mae: 0.0513
# Epoch 60/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 0.0011 - mse: 0.0011 - mape: 4.3803 - mae: 0.0265 - val_loss: 0.0045 - val_mse: 0.0045 - val_mape: 9.3002 - val_mae: 0.0551
# Epoch 61/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 0.0011 - mse: 0.0011 - mape: 4.3038 - mae: 0.0259 - val_loss: 0.0017 - val_mse: 0.0017 - val_mape: 5.2275 - val_mae: 0.0319
# Epoch 62/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 9.7493e-04 - mse: 9.7493e-04 - mape: 4.0080 - mae: 0.0243 - val_loss: 0.0023 - val_mse: 0.0023 - val_mape: 6.1072 - val_mae: 0.0385
# Epoch 63/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 0.0010 - mse: 0.0010 - mape: 4.1382 - mae: 0.0250 - val_loss: 0.0021 - val_mse: 0.0021 - val_mape: 5.8186 - val_mae: 0.0364
# Epoch 64/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 9.6650e-04 - mse: 9.6650e-04 - mape: 4.0541 - mae: 0.0242 - val_loss: 0.0021 - val_mse: 0.0021 - val_mape: 5.7712 - val_mae: 0.0340
# Epoch 65/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 9.4199e-04 - mse: 9.4199e-04 - mape: 3.9974 - mae: 0.0240 - val_loss: 0.0023 - val_mse: 0.0023 - val_mape: 5.9044 - val_mae: 0.0373
# Epoch 66/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 9.0616e-04 - mse: 9.0616e-04 - mape: 3.9679 - mae: 0.0238 - val_loss: 0.0020 - val_mse: 0.0020 - val_mape: 5.5349 - val_mae: 0.0344
# Epoch 67/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 9.6182e-04 - mse: 9.6182e-04 - mape: 4.0330 - mae: 0.0242 - val_loss: 0.0016 - val_mse: 0.0016 - val_mape: 5.0290 - val_mae: 0.0297
# Epoch 68/500
# 1324/1324 [==============================] - 84s 63ms/step - loss: 9.4851e-04 - mse: 9.4851e-04 - mape: 4.0132 - mae: 0.0243 - val_loss: 0.0021 - val_mse: 0.0021 - val_mape: 5.6904 - val_mae: 0.0357
# Epoch 69/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 9.5679e-04 - mse: 9.5679e-04 - mape: 4.0424 - mae: 0.0244 - val_loss: 0.0019 - val_mse: 0.0019 - val_mape: 5.6515 - val_mae: 0.0334
# Epoch 70/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 8.5338e-04 - mse: 8.5338e-04 - mape: 3.7496 - mae: 0.0227 - val_loss: 0.0021 - val_mse: 0.0021 - val_mape: 5.8728 - val_mae: 0.0350
# Epoch 71/500
# 1324/1324 [==============================] - 84s 63ms/step - loss: 8.4419e-04 - mse: 8.4419e-04 - mape: 3.7557 - mae: 0.0225 - val_loss: 0.0025 - val_mse: 0.0025 - val_mape: 5.9574 - val_mae: 0.0375
# Epoch 72/500
# 1324/1324 [==============================] - 84s 63ms/step - loss: 7.5924e-04 - mse: 7.5924e-04 - mape: 3.5829 - mae: 0.0217 - val_loss: 0.0057 - val_mse: 0.0057 - val_mape: 10.5237 - val_mae: 0.0668
# Epoch 73/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 7.8067e-04 - mse: 7.8067e-04 - mape: 3.6524 - mae: 0.0220 - val_loss: 0.0024 - val_mse: 0.0024 - val_mape: 6.4061 - val_mae: 0.0380
# Epoch 74/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 7.1993e-04 - mse: 7.1993e-04 - mape: 3.5298 - mae: 0.0213 - val_loss: 0.0017 - val_mse: 0.0017 - val_mape: 4.8657 - val_mae: 0.0298
# Epoch 75/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 7.0829e-04 - mse: 7.0829e-04 - mape: 3.5085 - mae: 0.0213 - val_loss: 0.0018 - val_mse: 0.0018 - val_mape: 5.1344 - val_mae: 0.0306
# Epoch 76/500
# 1324/1324 [==============================] - 84s 63ms/step - loss: 7.4947e-04 - mse: 7.4947e-04 - mape: 3.5610 - mae: 0.0216 - val_loss: 0.0022 - val_mse: 0.0022 - val_mape: 5.9479 - val_mae: 0.0353
# Epoch 77/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 7.7530e-04 - mse: 7.7530e-04 - mape: 3.5798 - mae: 0.0217 - val_loss: 0.0019 - val_mse: 0.0019 - val_mape: 5.5386 - val_mae: 0.0329
# Epoch 78/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 6.2092e-04 - mse: 6.2092e-04 - mape: 3.2934 - mae: 0.0198 - val_loss: 0.0026 - val_mse: 0.0026 - val_mape: 6.6836 - val_mae: 0.0398
# Epoch 79/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 6.3890e-04 - mse: 6.3890e-04 - mape: 3.3047 - mae: 0.0200 - val_loss: 0.0018 - val_mse: 0.0018 - val_mape: 5.0386 - val_mae: 0.0305
# Epoch 80/500
# 1324/1324 [==============================] - 85s 64ms/step - loss: 6.3403e-04 - mse: 6.3403e-04 - mape: 3.3037 - mae: 0.0200 - val_loss: 0.0027 - val_mse: 0.0027 - val_mape: 6.8075 - val_mae: 0.0422
# Epoch 81/500
# 1324/1324 [==============================] - 85s 64ms/step - loss: 6.1742e-04 - mse: 6.1742e-04 - mape: 3.1888 - mae: 0.0193 - val_loss: 0.0015 - val_mse: 0.0015 - val_mape: 4.6684 - val_mae: 0.0282
# Epoch 82/500
# 1324/1324 [==============================] - 85s 64ms/step - loss: 6.3544e-04 - mse: 6.3544e-04 - mape: 3.3352 - mae: 0.0201 - val_loss: 0.0020 - val_mse: 0.0020 - val_mape: 5.2408 - val_mae: 0.0308
# Epoch 83/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 5.8379e-04 - mse: 5.8379e-04 - mape: 3.2236 - mae: 0.0194 - val_loss: 0.0028 - val_mse: 0.0028 - val_mape: 6.8401 - val_mae: 0.0426
# Epoch 84/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 5.8527e-04 - mse: 5.8527e-04 - mape: 3.1589 - mae: 0.0191 - val_loss: 0.0018 - val_mse: 0.0018 - val_mape: 5.0805 - val_mae: 0.0306
# Epoch 85/500
# 1324/1324 [==============================] - 84s 63ms/step - loss: 5.3695e-04 - mse: 5.3695e-04 - mape: 3.0396 - mae: 0.0184 - val_loss: 0.0019 - val_mse: 0.0019 - val_mape: 5.2886 - val_mae: 0.0313
# Epoch 86/500
# 1324/1324 [==============================] - 84s 63ms/step - loss: 5.1674e-04 - mse: 5.1674e-04 - mape: 2.9780 - mae: 0.0181 - val_loss: 0.0016 - val_mse: 0.0016 - val_mape: 4.9790 - val_mae: 0.0300
# Epoch 87/500
# 1324/1324 [==============================] - 84s 63ms/step - loss: 5.1364e-04 - mse: 5.1364e-04 - mape: 2.9801 - mae: 0.0180 - val_loss: 0.0019 - val_mse: 0.0019 - val_mape: 5.4517 - val_mae: 0.0334
# Epoch 88/500
# 1324/1324 [==============================] - 84s 63ms/step - loss: 5.1579e-04 - mse: 5.1579e-04 - mape: 2.9795 - mae: 0.0179 - val_loss: 0.0014 - val_mse: 0.0014 - val_mape: 4.4158 - val_mae: 0.0267
# Epoch 89/500
# 1324/1324 [==============================] - 84s 63ms/step - loss: 5.3436e-04 - mse: 5.3436e-04 - mape: 2.9853 - mae: 0.0181 - val_loss: 0.0033 - val_mse: 0.0033 - val_mape: 7.3170 - val_mae: 0.0459
# Epoch 90/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 4.8035e-04 - mse: 4.8035e-04 - mape: 2.8074 - mae: 0.0170 - val_loss: 0.0014 - val_mse: 0.0014 - val_mape: 4.6434 - val_mae: 0.0274
# Epoch 91/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 5.0792e-04 - mse: 5.0792e-04 - mape: 2.9484 - mae: 0.0176 - val_loss: 0.0019 - val_mse: 0.0019 - val_mape: 5.4430 - val_mae: 0.0317
# Epoch 92/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 5.3502e-04 - mse: 5.3502e-04 - mape: 3.0039 - mae: 0.0181 - val_loss: 0.0019 - val_mse: 0.0019 - val_mape: 5.1616 - val_mae: 0.0316
# Epoch 93/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 4.6543e-04 - mse: 4.6543e-04 - mape: 2.8140 - mae: 0.0170 - val_loss: 0.0017 - val_mse: 0.0017 - val_mape: 4.8093 - val_mae: 0.0288
# Epoch 94/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 4.3240e-04 - mse: 4.3240e-04 - mape: 2.6939 - mae: 0.0165 - val_loss: 0.0019 - val_mse: 0.0019 - val_mape: 5.0814 - val_mae: 0.0310
# Epoch 95/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 4.2830e-04 - mse: 4.2830e-04 - mape: 2.6641 - mae: 0.0162 - val_loss: 0.0021 - val_mse: 0.0021 - val_mape: 5.8819 - val_mae: 0.0367
# Epoch 96/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 4.8973e-04 - mse: 4.8973e-04 - mape: 2.9141 - mae: 0.0177 - val_loss: 0.0014 - val_mse: 0.0014 - val_mape: 4.5289 - val_mae: 0.0273
# Epoch 97/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 4.1867e-04 - mse: 4.1867e-04 - mape: 2.6329 - mae: 0.0160 - val_loss: 0.0023 - val_mse: 0.0023 - val_mape: 6.1997 - val_mae: 0.0384
# Epoch 98/500
# 1324/1324 [==============================] - 84s 63ms/step - loss: 3.9160e-04 - mse: 3.9160e-04 - mape: 2.6076 - mae: 0.0159 - val_loss: 0.0032 - val_mse: 0.0032 - val_mape: 7.1851 - val_mae: 0.0451
# Epoch 99/500
# 1324/1324 [==============================] - 84s 63ms/step - loss: 4.0682e-04 - mse: 4.0682e-04 - mape: 2.6159 - mae: 0.0157 - val_loss: 0.0022 - val_mse: 0.0022 - val_mape: 5.9069 - val_mae: 0.0369
# Epoch 100/500
# 1324/1324 [==============================] - 84s 63ms/step - loss: 3.6268e-04 - mse: 3.6268e-04 - mape: 2.4784 - mae: 0.0150 - val_loss: 0.0017 - val_mse: 0.0017 - val_mape: 4.9820 - val_mae: 0.0306
# Epoch 101/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 3.2619e-04 - mse: 3.2619e-04 - mape: 2.3757 - mae: 0.0144 - val_loss: 0.0017 - val_mse: 0.0017 - val_mape: 5.0229 - val_mae: 0.0306
# Epoch 102/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 3.6858e-04 - mse: 3.6858e-04 - mape: 2.4922 - mae: 0.0151 - val_loss: 0.0024 - val_mse: 0.0024 - val_mape: 5.9262 - val_mae: 0.0363
# Epoch 103/500
# 1324/1324 [==============================] - 84s 63ms/step - loss: 3.7034e-04 - mse: 3.7034e-04 - mape: 2.4729 - mae: 0.0150 - val_loss: 0.0021 - val_mse: 0.0021 - val_mape: 5.6682 - val_mae: 0.0352
# Epoch 104/500
# 1324/1324 [==============================] - 85s 64ms/step - loss: 3.5316e-04 - mse: 3.5316e-04 - mape: 2.4500 - mae: 0.0147 - val_loss: 0.0017 - val_mse: 0.0017 - val_mape: 4.9560 - val_mae: 0.0299
# Epoch 105/500
# 1324/1324 [==============================] - 85s 64ms/step - loss: 3.7315e-04 - mse: 3.7315e-04 - mape: 2.5032 - mae: 0.0152 - val_loss: 0.0018 - val_mse: 0.0018 - val_mape: 4.8598 - val_mae: 0.0300
# Epoch 106/500
# 1324/1324 [==============================] - 85s 64ms/step - loss: 3.8448e-04 - mse: 3.8448e-04 - mape: 2.5470 - mae: 0.0155 - val_loss: 0.0023 - val_mse: 0.0023 - val_mape: 6.1500 - val_mae: 0.0360
# Epoch 107/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 3.5496e-04 - mse: 3.5496e-04 - mape: 2.4668 - mae: 0.0149 - val_loss: 0.0018 - val_mse: 0.0018 - val_mape: 4.9770 - val_mae: 0.0296
# Epoch 108/500
# 1324/1324 [==============================] - 84s 63ms/step - loss: 3.6689e-04 - mse: 3.6689e-04 - mape: 2.4512 - mae: 0.0148 - val_loss: 0.0015 - val_mse: 0.0015 - val_mape: 4.5948 - val_mae: 0.0278
# Epoch 109/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 3.1838e-04 - mse: 3.1838e-04 - mape: 2.3123 - mae: 0.0140 - val_loss: 0.0019 - val_mse: 0.0019 - val_mape: 5.3754 - val_mae: 0.0332
# Epoch 110/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 3.2120e-04 - mse: 3.2120e-04 - mape: 2.3020 - mae: 0.0140 - val_loss: 0.0021 - val_mse: 0.0021 - val_mape: 5.7420 - val_mae: 0.0341
# Epoch 111/500
# 1324/1324 [==============================] - 84s 63ms/step - loss: 3.5661e-04 - mse: 3.5661e-04 - mape: 2.4214 - mae: 0.0147 - val_loss: 0.0018 - val_mse: 0.0018 - val_mape: 5.0883 - val_mae: 0.0308
# Epoch 112/500
# 1324/1324 [==============================] - 84s 63ms/step - loss: 3.0035e-04 - mse: 3.0035e-04 - mape: 2.2795 - mae: 0.0138 - val_loss: 0.0018 - val_mse: 0.0018 - val_mape: 4.8341 - val_mae: 0.0293
# Epoch 113/500
# 1324/1324 [==============================] - 84s 63ms/step - loss: 3.1108e-04 - mse: 3.1108e-04 - mape: 2.2893 - mae: 0.0140 - val_loss: 0.0017 - val_mse: 0.0017 - val_mape: 5.0098 - val_mae: 0.0301
# Epoch 114/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.9977e-04 - mse: 2.9977e-04 - mape: 2.2387 - mae: 0.0136 - val_loss: 0.0019 - val_mse: 0.0019 - val_mape: 5.3862 - val_mae: 0.0332
# Epoch 115/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.8389e-04 - mse: 2.8389e-04 - mape: 2.2043 - mae: 0.0134 - val_loss: 0.0019 - val_mse: 0.0019 - val_mape: 5.4055 - val_mae: 0.0334
# Epoch 116/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.8822e-04 - mse: 2.8822e-04 - mape: 2.2069 - mae: 0.0133 - val_loss: 0.0017 - val_mse: 0.0017 - val_mape: 5.0222 - val_mae: 0.0309
# Epoch 117/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.8365e-04 - mse: 2.8365e-04 - mape: 2.1677 - mae: 0.0131 - val_loss: 0.0015 - val_mse: 0.0015 - val_mape: 4.4944 - val_mae: 0.0271
# Epoch 118/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.7474e-04 - mse: 2.7474e-04 - mape: 2.0765 - mae: 0.0126 - val_loss: 0.0014 - val_mse: 0.0014 - val_mape: 4.4783 - val_mae: 0.0268
# Epoch 119/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.5540e-04 - mse: 2.5540e-04 - mape: 2.0896 - mae: 0.0126 - val_loss: 0.0016 - val_mse: 0.0016 - val_mape: 4.5831 - val_mae: 0.0275
# Epoch 120/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.4311e-04 - mse: 2.4311e-04 - mape: 2.0377 - mae: 0.0124 - val_loss: 0.0015 - val_mse: 0.0015 - val_mape: 4.5001 - val_mae: 0.0268
# Epoch 121/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.7758e-04 - mse: 2.7758e-04 - mape: 2.1498 - mae: 0.0130 - val_loss: 0.0030 - val_mse: 0.0030 - val_mape: 7.4072 - val_mae: 0.0444
# Epoch 122/500
# 1324/1324 [==============================] - 84s 63ms/step - loss: 2.6353e-04 - mse: 2.6353e-04 - mape: 2.0586 - mae: 0.0125 - val_loss: 0.0018 - val_mse: 0.0018 - val_mape: 5.1986 - val_mae: 0.0321
# Epoch 123/500
# 1324/1324 [==============================] - 84s 63ms/step - loss: 2.4343e-04 - mse: 2.4343e-04 - mape: 2.0374 - mae: 0.0123 - val_loss: 0.0019 - val_mse: 0.0019 - val_mape: 4.9577 - val_mae: 0.0298
# Epoch 124/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.4755e-04 - mse: 2.4755e-04 - mape: 2.0594 - mae: 0.0125 - val_loss: 0.0022 - val_mse: 0.0022 - val_mape: 5.4116 - val_mae: 0.0336
# Epoch 125/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.6582e-04 - mse: 2.6582e-04 - mape: 2.1254 - mae: 0.0129 - val_loss: 0.0015 - val_mse: 0.0015 - val_mape: 4.6176 - val_mae: 0.0277
# Epoch 126/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.2341e-04 - mse: 2.2341e-04 - mape: 1.9291 - mae: 0.0117 - val_loss: 0.0017 - val_mse: 0.0017 - val_mape: 4.8319 - val_mae: 0.0294
# Epoch 127/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.3741e-04 - mse: 2.3741e-04 - mape: 1.9896 - mae: 0.0121 - val_loss: 0.0025 - val_mse: 0.0025 - val_mape: 6.3244 - val_mae: 0.0369
# Epoch 128/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.2702e-04 - mse: 2.2702e-04 - mape: 1.9618 - mae: 0.0119 - val_loss: 0.0017 - val_mse: 0.0017 - val_mape: 4.7167 - val_mae: 0.0287
# Epoch 129/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.6154e-04 - mse: 2.6154e-04 - mape: 2.0908 - mae: 0.0127 - val_loss: 0.0016 - val_mse: 0.0016 - val_mape: 4.5583 - val_mae: 0.0277
# Epoch 130/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.5654e-04 - mse: 2.5654e-04 - mape: 1.9869 - mae: 0.0122 - val_loss: 0.0019 - val_mse: 0.0019 - val_mape: 5.1193 - val_mae: 0.0307
# Epoch 131/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.2523e-04 - mse: 2.2523e-04 - mape: 1.9486 - mae: 0.0118 - val_loss: 0.0015 - val_mse: 0.0015 - val_mape: 4.6936 - val_mae: 0.0285
# Epoch 132/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.2474e-04 - mse: 2.2474e-04 - mape: 1.9879 - mae: 0.0121 - val_loss: 0.0017 - val_mse: 0.0017 - val_mape: 4.6874 - val_mae: 0.0282
# Epoch 133/500
# 1324/1324 [==============================] - 84s 63ms/step - loss: 2.1822e-04 - mse: 2.1822e-04 - mape: 1.8951 - mae: 0.0115 - val_loss: 0.0017 - val_mse: 0.0017 - val_mape: 4.7416 - val_mae: 0.0283
# Epoch 134/500
# 1324/1324 [==============================] - 85s 64ms/step - loss: 2.1497e-04 - mse: 2.1497e-04 - mape: 1.9211 - mae: 0.0117 - val_loss: 0.0018 - val_mse: 0.0018 - val_mape: 5.0184 - val_mae: 0.0303
# Epoch 135/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.0479e-04 - mse: 2.0479e-04 - mape: 1.8932 - mae: 0.0114 - val_loss: 0.0018 - val_mse: 0.0018 - val_mape: 5.1596 - val_mae: 0.0306
# Epoch 136/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.3013e-04 - mse: 2.3013e-04 - mape: 1.9528 - mae: 0.0119 - val_loss: 0.0016 - val_mse: 0.0016 - val_mape: 4.7366 - val_mae: 0.0291
# Epoch 137/500
# 1324/1324 [==============================] - 84s 63ms/step - loss: 2.0653e-04 - mse: 2.0653e-04 - mape: 1.8420 - mae: 0.0112 - val_loss: 0.0022 - val_mse: 0.0022 - val_mape: 5.6574 - val_mae: 0.0336
# Epoch 138/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.0556e-04 - mse: 2.0556e-04 - mape: 1.8527 - mae: 0.0113 - val_loss: 0.0024 - val_mse: 0.0024 - val_mape: 5.8547 - val_mae: 0.0360
# Epoch 139/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 0.0036 - mse: 0.0036 - mape: 6.0478 - mae: 0.0370 - val_loss: 0.0016 - val_mse: 0.0016 - val_mape: 4.9237 - val_mae: 0.0294
# Epoch 140/500
# 1324/1324 [==============================] - 85s 64ms/step - loss: 0.0018 - mse: 0.0018 - mape: 3.6439 - mae: 0.0222 - val_loss: 0.0024 - val_mse: 0.0024 - val_mape: 6.2579 - val_mae: 0.0377
# Epoch 141/500
# 1324/1324 [==============================] - 85s 64ms/step - loss: 0.0013 - mse: 0.0013 - mape: 3.4146 - mae: 0.0207 - val_loss: 0.5280 - val_mse: 0.5280 - val_mape: 115.1016 - val_mae: 0.7052
# Epoch 142/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 0.0028 - mse: 0.0028 - mape: 4.0604 - mae: 0.0248 - val_loss: 0.0034 - val_mse: 0.0034 - val_mape: 7.8237 - val_mae: 0.0455
# Epoch 143/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 4.4221e-04 - mse: 4.4221e-04 - mape: 2.6361 - mae: 0.0160 - val_loss: 0.0016 - val_mse: 0.0016 - val_mape: 4.5480 - val_mae: 0.0279
# Epoch 144/500
# 1324/1324 [==============================] - 85s 64ms/step - loss: 6.3268e-04 - mse: 6.3268e-04 - mape: 2.9763 - mae: 0.0181 - val_loss: 0.0021 - val_mse: 0.0021 - val_mape: 5.5649 - val_mae: 0.0347
# Epoch 145/500
# 1324/1324 [==============================] - 85s 64ms/step - loss: 3.4754e-04 - mse: 3.4754e-04 - mape: 2.3617 - mae: 0.0143 - val_loss: 0.0016 - val_mse: 0.0016 - val_mape: 4.7144 - val_mae: 0.0283
# Epoch 146/500
# 1324/1324 [==============================] - 85s 64ms/step - loss: 2.8109e-04 - mse: 2.8109e-04 - mape: 2.1247 - mae: 0.0129 - val_loss: 0.0018 - val_mse: 0.0018 - val_mape: 4.9533 - val_mae: 0.0297
# Epoch 147/500
# 1324/1324 [==============================] - 85s 64ms/step - loss: 2.6833e-04 - mse: 2.6833e-04 - mape: 2.0641 - mae: 0.0126 - val_loss: 0.0023 - val_mse: 0.0023 - val_mape: 6.0931 - val_mae: 0.0355
# Epoch 148/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.2554e-04 - mse: 2.2554e-04 - mape: 1.9206 - mae: 0.0117 - val_loss: 0.0016 - val_mse: 0.0016 - val_mape: 4.3617 - val_mae: 0.0263
# Epoch 149/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.1019e-04 - mse: 2.1019e-04 - mape: 1.8929 - mae: 0.0115 - val_loss: 0.0018 - val_mse: 0.0018 - val_mape: 5.0467 - val_mae: 0.0309
# Epoch 150/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.4796e-04 - mse: 2.4796e-04 - mape: 1.9459 - mae: 0.0118 - val_loss: 0.0017 - val_mse: 0.0017 - val_mape: 4.7858 - val_mae: 0.0292
# Epoch 151/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 1.9458e-04 - mse: 1.9458e-04 - mape: 1.7845 - mae: 0.0108 - val_loss: 0.0015 - val_mse: 0.0015 - val_mape: 4.6162 - val_mae: 0.0277
# Epoch 152/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 1.8856e-04 - mse: 1.8856e-04 - mape: 1.7453 - mae: 0.0106 - val_loss: 0.0018 - val_mse: 0.0018 - val_mape: 5.1176 - val_mae: 0.0305
# Epoch 153/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.1416e-04 - mse: 2.1416e-04 - mape: 1.8096 - mae: 0.0111 - val_loss: 0.0015 - val_mse: 0.0015 - val_mape: 4.5110 - val_mae: 0.0270
# Epoch 154/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.0015e-04 - mse: 2.0015e-04 - mape: 1.7416 - mae: 0.0105 - val_loss: 0.0016 - val_mse: 0.0016 - val_mape: 4.6557 - val_mae: 0.0283
# Epoch 155/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 1.9792e-04 - mse: 1.9792e-04 - mape: 1.8079 - mae: 0.0110 - val_loss: 0.0020 - val_mse: 0.0020 - val_mape: 5.5109 - val_mae: 0.0328
# Epoch 156/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 1.8691e-04 - mse: 1.8691e-04 - mape: 1.7240 - mae: 0.0104 - val_loss: 0.0017 - val_mse: 0.0017 - val_mape: 4.6435 - val_mae: 0.0286
# Epoch 157/500
# 1324/1324 [==============================] - 84s 63ms/step - loss: 1.9569e-04 - mse: 1.9569e-04 - mape: 1.8094 - mae: 0.0109 - val_loss: 0.0023 - val_mse: 0.0023 - val_mape: 6.2685 - val_mae: 0.0374
# Epoch 158/500
# 1324/1324 [==============================] - 84s 63ms/step - loss: 2.0697e-04 - mse: 2.0697e-04 - mape: 1.8261 - mae: 0.0111 - val_loss: 0.0018 - val_mse: 0.0018 - val_mape: 5.1651 - val_mae: 0.0305
# Epoch 159/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 1.7821e-04 - mse: 1.7821e-04 - mape: 1.7132 - mae: 0.0105 - val_loss: 0.0033 - val_mse: 0.0033 - val_mape: 6.9753 - val_mae: 0.0441
# Epoch 160/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 1.7957e-04 - mse: 1.7957e-04 - mape: 1.7250 - mae: 0.0105 - val_loss: 0.0017 - val_mse: 0.0017 - val_mape: 4.9467 - val_mae: 0.0293
# Epoch 161/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 1.5910e-04 - mse: 1.5910e-04 - mape: 1.6460 - mae: 0.0100 - val_loss: 0.0017 - val_mse: 0.0017 - val_mape: 5.0095 - val_mae: 0.0299
# Epoch 162/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 1.4667e-04 - mse: 1.4667e-04 - mape: 1.5494 - mae: 0.0094 - val_loss: 0.0020 - val_mse: 0.0020 - val_mape: 5.6306 - val_mae: 0.0333
# Epoch 163/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 1.7301e-04 - mse: 1.7301e-04 - mape: 1.7157 - mae: 0.0104 - val_loss: 0.0015 - val_mse: 0.0015 - val_mape: 4.5502 - val_mae: 0.0272
# Epoch 164/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 1.5919e-04 - mse: 1.5919e-04 - mape: 1.6322 - mae: 0.0099 - val_loss: 0.0015 - val_mse: 0.0015 - val_mape: 4.6269 - val_mae: 0.0277
# Epoch 165/500
# 1324/1324 [==============================] - 84s 63ms/step - loss: 1.4610e-04 - mse: 1.4610e-04 - mape: 1.5547 - mae: 0.0094 - val_loss: 0.0019 - val_mse: 0.0019 - val_mape: 5.1257 - val_mae: 0.0313
# Epoch 166/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 1.4789e-04 - mse: 1.4789e-04 - mape: 1.5601 - mae: 0.0094 - val_loss: 0.0018 - val_mse: 0.0018 - val_mape: 5.0909 - val_mae: 0.0299
# Epoch 167/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 1.5574e-04 - mse: 1.5574e-04 - mape: 1.5848 - mae: 0.0097 - val_loss: 0.0016 - val_mse: 0.0016 - val_mape: 4.8274 - val_mae: 0.0289
# Epoch 168/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 1.4865e-04 - mse: 1.4865e-04 - mape: 1.5635 - mae: 0.0095 - val_loss: 0.0017 - val_mse: 0.0017 - val_mape: 4.8063 - val_mae: 0.0297
# Epoch 169/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 1.4433e-04 - mse: 1.4433e-04 - mape: 1.5246 - mae: 0.0093 - val_loss: 0.0022 - val_mse: 0.0022 - val_mape: 5.5652 - val_mae: 0.0348
# Epoch 170/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 1.4999e-04 - mse: 1.4999e-04 - mape: 1.5591 - mae: 0.0095 - val_loss: 0.0022 - val_mse: 0.0022 - val_mape: 5.5765 - val_mae: 0.0348
# Epoch 171/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 1.4053e-04 - mse: 1.4053e-04 - mape: 1.5420 - mae: 0.0093 - val_loss: 0.0024 - val_mse: 0.0024 - val_mape: 6.4187 - val_mae: 0.0376
# Epoch 172/500
# 1324/1324 [==============================] - 85s 64ms/step - loss: 1.5305e-04 - mse: 1.5305e-04 - mape: 1.5380 - mae: 0.0093 - val_loss: 0.0015 - val_mse: 0.0015 - val_mape: 4.5650 - val_mae: 0.0275
# Epoch 173/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 1.6104e-04 - mse: 1.6104e-04 - mape: 1.6079 - mae: 0.0098 - val_loss: 0.0016 - val_mse: 0.0016 - val_mape: 4.6432 - val_mae: 0.0284
# Epoch 174/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 1.4952e-04 - mse: 1.4952e-04 - mape: 1.5820 - mae: 0.0095 - val_loss: 0.0019 - val_mse: 0.0019 - val_mape: 5.2870 - val_mae: 0.0328
# Epoch 175/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 1.4680e-04 - mse: 1.4680e-04 - mape: 1.5282 - mae: 0.0093 - val_loss: 0.0016 - val_mse: 0.0016 - val_mape: 4.7803 - val_mae: 0.0288
# Epoch 176/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 1.4316e-04 - mse: 1.4316e-04 - mape: 1.5333 - mae: 0.0093 - val_loss: 0.0015 - val_mse: 0.0015 - val_mape: 4.4522 - val_mae: 0.0269
# Epoch 177/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 1.3819e-04 - mse: 1.3819e-04 - mape: 1.5191 - mae: 0.0092 - val_loss: 0.0021 - val_mse: 0.0021 - val_mape: 5.6841 - val_mae: 0.0354
# Epoch 178/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 1.4730e-04 - mse: 1.4730e-04 - mape: 1.5436 - mae: 0.0094 - val_loss: 0.0017 - val_mse: 0.0017 - val_mape: 4.7995 - val_mae: 0.0297
# Epoch 179/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 1.4364e-04 - mse: 1.4364e-04 - mape: 1.5252 - mae: 0.0092 - val_loss: 0.0017 - val_mse: 0.0017 - val_mape: 4.8169 - val_mae: 0.0294
# Epoch 180/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 1.4361e-04 - mse: 1.4360e-04 - mape: 1.5280 - mae: 0.0093 - val_loss: 0.0018 - val_mse: 0.0018 - val_mape: 5.0922 - val_mae: 0.0314
# Epoch 181/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 1.2725e-04 - mse: 1.2725e-04 - mape: 1.4263 - mae: 0.0087 - val_loss: 0.0017 - val_mse: 0.0017 - val_mape: 4.8477 - val_mae: 0.0300
# Epoch 182/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 1.3710e-04 - mse: 1.3710e-04 - mape: 1.4854 - mae: 0.0090 - val_loss: 0.0015 - val_mse: 0.0015 - val_mape: 4.5254 - val_mae: 0.0275
# Epoch 183/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 1.3406e-04 - mse: 1.3406e-04 - mape: 1.4541 - mae: 0.0088 - val_loss: 0.0020 - val_mse: 0.0020 - val_mape: 5.6052 - val_mae: 0.0330
# Epoch 184/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 1.2770e-04 - mse: 1.2770e-04 - mape: 1.4562 - mae: 0.0088 - val_loss: 0.0017 - val_mse: 0.0017 - val_mape: 4.8173 - val_mae: 0.0286
# Epoch 185/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 1.2194e-04 - mse: 1.2194e-04 - mape: 1.3798 - mae: 0.0084 - val_loss: 0.0019 - val_mse: 0.0019 - val_mape: 5.5228 - val_mae: 0.0323
# Epoch 186/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 1.2136e-04 - mse: 1.2136e-04 - mape: 1.3964 - mae: 0.0085 - val_loss: 0.0017 - val_mse: 0.0017 - val_mape: 4.8714 - val_mae: 0.0293
# Epoch 187/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 1.2013e-04 - mse: 1.2013e-04 - mape: 1.4083 - mae: 0.0086 - val_loss: 0.0023 - val_mse: 0.0023 - val_mape: 6.1826 - val_mae: 0.0363
# Epoch 188/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 1.2896e-04 - mse: 1.2896e-04 - mape: 1.4223 - mae: 0.0086 - val_loss: 0.0016 - val_mse: 0.0016 - val_mape: 4.7512 - val_mae: 0.0284
# Epoch 189/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 1.1677e-04 - mse: 1.1677e-04 - mape: 1.3773 - mae: 0.0083 - val_loss: 0.0017 - val_mse: 0.0017 - val_mape: 5.1742 - val_mae: 0.0306
# Epoch 190/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 1.1885e-04 - mse: 1.1885e-04 - mape: 1.3734 - mae: 0.0083 - val_loss: 0.0016 - val_mse: 0.0016 - val_mape: 4.8633 - val_mae: 0.0289
# Epoch 191/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 1.2737e-04 - mse: 1.2737e-04 - mape: 1.4126 - mae: 0.0086 - val_loss: 0.0016 - val_mse: 0.0016 - val_mape: 4.7659 - val_mae: 0.0283
# Epoch 192/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 1.1380e-04 - mse: 1.1380e-04 - mape: 1.3650 - mae: 0.0082 - val_loss: 0.0016 - val_mse: 0.0016 - val_mape: 4.7595 - val_mae: 0.0289
# Epoch 193/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 1.2144e-04 - mse: 1.2144e-04 - mape: 1.4016 - mae: 0.0085 - val_loss: 0.0016 - val_mse: 0.0016 - val_mape: 4.7257 - val_mae: 0.0288
# Epoch 194/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 1.2831e-04 - mse: 1.2831e-04 - mape: 1.4326 - mae: 0.0087 - val_loss: 0.0015 - val_mse: 0.0015 - val_mape: 4.4603 - val_mae: 0.0271
# Epoch 195/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 1.1291e-04 - mse: 1.1291e-04 - mape: 1.3520 - mae: 0.0082 - val_loss: 0.0017 - val_mse: 0.0017 - val_mape: 5.0019 - val_mae: 0.0304
# Epoch 196/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 1.1582e-04 - mse: 1.1582e-04 - mape: 1.3802 - mae: 0.0083 - val_loss: 0.0016 - val_mse: 0.0016 - val_mape: 4.8478 - val_mae: 0.0288
# Epoch 197/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 1.1384e-04 - mse: 1.1384e-04 - mape: 1.3398 - mae: 0.0081 - val_loss: 0.0015 - val_mse: 0.0015 - val_mape: 4.3799 - val_mae: 0.0265
# Epoch 198/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 1.0478e-04 - mse: 1.0478e-04 - mape: 1.3106 - mae: 0.0080 - val_loss: 0.0018 - val_mse: 0.0018 - val_mape: 5.0675 - val_mae: 0.0313
# Epoch 199/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 1.0677e-04 - mse: 1.0677e-04 - mape: 1.3140 - mae: 0.0080 - val_loss: 0.0015 - val_mse: 0.0015 - val_mape: 4.5449 - val_mae: 0.0270
# Epoch 200/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 1.0572e-04 - mse: 1.0572e-04 - mape: 1.2903 - mae: 0.0079 - val_loss: 0.0014 - val_mse: 0.0014 - val_mape: 4.3476 - val_mae: 0.0263
# Epoch 201/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 1.0804e-04 - mse: 1.0804e-04 - mape: 1.3071 - mae: 0.0079 - val_loss: 0.0015 - val_mse: 0.0015 - val_mape: 4.4647 - val_mae: 0.0266
# Epoch 202/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 1.0430e-04 - mse: 1.0430e-04 - mape: 1.3102 - mae: 0.0080 - val_loss: 0.0015 - val_mse: 0.0015 - val_mape: 4.5453 - val_mae: 0.0272
# Epoch 203/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 9.6425e-05 - mse: 9.6425e-05 - mape: 1.2399 - mae: 0.0075 - val_loss: 0.0014 - val_mse: 0.0014 - val_mape: 4.3006 - val_mae: 0.0259
# Epoch 204/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 9.9653e-05 - mse: 9.9653e-05 - mape: 1.2857 - mae: 0.0078 - val_loss: 0.0015 - val_mse: 0.0015 - val_mape: 4.4072 - val_mae: 0.0268
# Epoch 205/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 9.6361e-05 - mse: 9.6361e-05 - mape: 1.2884 - mae: 0.0078 - val_loss: 0.0016 - val_mse: 0.0016 - val_mape: 4.8028 - val_mae: 0.0286
# Epoch 206/500
# 1324/1324 [==============================] - 84s 63ms/step - loss: 9.7065e-05 - mse: 9.7065e-05 - mape: 1.2525 - mae: 0.0076 - val_loss: 0.0014 - val_mse: 0.0014 - val_mape: 4.3766 - val_mae: 0.0263
# Epoch 207/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 9.8325e-05 - mse: 9.8325e-05 - mape: 1.2772 - mae: 0.0078 - val_loss: 0.0014 - val_mse: 0.0014 - val_mape: 4.4381 - val_mae: 0.0269
# Epoch 208/500
# 1324/1324 [==============================] - 85s 64ms/step - loss: 9.5617e-05 - mse: 9.5617e-05 - mape: 1.2573 - mae: 0.0076 - val_loss: 0.0014 - val_mse: 0.0014 - val_mape: 4.3627 - val_mae: 0.0264
# Epoch 209/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 9.9674e-05 - mse: 9.9674e-05 - mape: 1.2598 - mae: 0.0077 - val_loss: 0.0016 - val_mse: 0.0016 - val_mape: 4.8533 - val_mae: 0.0292
# Epoch 210/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 9.4287e-05 - mse: 9.4287e-05 - mape: 1.2275 - mae: 0.0075 - val_loss: 0.0015 - val_mse: 0.0015 - val_mape: 4.5017 - val_mae: 0.0273
# Epoch 211/500
# 1324/1324 [==============================] - 84s 63ms/step - loss: 9.1401e-05 - mse: 9.1401e-05 - mape: 1.2102 - mae: 0.0074 - val_loss: 0.0015 - val_mse: 0.0015 - val_mape: 4.5231 - val_mae: 0.0272
# Epoch 212/500
# 1324/1324 [==============================] - 84s 63ms/step - loss: 9.2175e-05 - mse: 9.2175e-05 - mape: 1.2109 - mae: 0.0073 - val_loss: 0.0015 - val_mse: 0.0015 - val_mape: 4.6528 - val_mae: 0.0283
# Epoch 213/500
# 1324/1324 [==============================] - 84s 63ms/step - loss: 1.0270e-04 - mse: 1.0270e-04 - mape: 1.2836 - mae: 0.0078 - val_loss: 0.0015 - val_mse: 0.0015 - val_mape: 4.4802 - val_mae: 0.0275
# Epoch 214/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 9.1044e-05 - mse: 9.1044e-05 - mape: 1.2227 - mae: 0.0074 - val_loss: 0.0017 - val_mse: 0.0017 - val_mape: 4.8117 - val_mae: 0.0295
# Epoch 215/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 1.0045e-04 - mse: 1.0045e-04 - mape: 1.2769 - mae: 0.0077 - val_loss: 0.0016 - val_mse: 0.0016 - val_mape: 4.6398 - val_mae: 0.0279
# Epoch 216/500
# 1324/1324 [==============================] - 85s 64ms/step - loss: 8.9977e-05 - mse: 8.9977e-05 - mape: 1.1867 - mae: 0.0072 - val_loss: 0.0015 - val_mse: 0.0015 - val_mape: 4.6405 - val_mae: 0.0275
# Epoch 217/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 9.8185e-05 - mse: 9.8185e-05 - mape: 1.2461 - mae: 0.0076 - val_loss: 0.0017 - val_mse: 0.0017 - val_mape: 5.0598 - val_mae: 0.0302
# Epoch 218/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 9.4879e-05 - mse: 9.4879e-05 - mape: 1.2540 - mae: 0.0076 - val_loss: 0.0016 - val_mse: 0.0016 - val_mape: 4.9364 - val_mae: 0.0298
# Epoch 219/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 8.4175e-05 - mse: 8.4175e-05 - mape: 1.1746 - mae: 0.0072 - val_loss: 0.0017 - val_mse: 0.0017 - val_mape: 4.9440 - val_mae: 0.0298
# Epoch 220/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 9.2884e-05 - mse: 9.2884e-05 - mape: 1.1889 - mae: 0.0073 - val_loss: 0.0016 - val_mse: 0.0016 - val_mape: 4.8009 - val_mae: 0.0284
# Epoch 221/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 8.6401e-05 - mse: 8.6401e-05 - mape: 1.1916 - mae: 0.0072 - val_loss: 0.0016 - val_mse: 0.0016 - val_mape: 4.7324 - val_mae: 0.0278
# Epoch 222/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 9.4146e-05 - mse: 9.4146e-05 - mape: 1.2428 - mae: 0.0075 - val_loss: 0.0013 - val_mse: 0.0013 - val_mape: 4.1314 - val_mae: 0.0250
# Epoch 223/500
# 1324/1324 [==============================] - 85s 64ms/step - loss: 8.9991e-05 - mse: 8.9991e-05 - mape: 1.1761 - mae: 0.0072 - val_loss: 0.0015 - val_mse: 0.0015 - val_mape: 4.5067 - val_mae: 0.0274
# Epoch 224/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 8.2395e-05 - mse: 8.2395e-05 - mape: 1.1471 - mae: 0.0070 - val_loss: 0.0016 - val_mse: 0.0016 - val_mape: 4.7323 - val_mae: 0.0290
# Epoch 225/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 8.6426e-05 - mse: 8.6426e-05 - mape: 1.1902 - mae: 0.0072 - val_loss: 0.0015 - val_mse: 0.0015 - val_mape: 4.5551 - val_mae: 0.0277
# Epoch 226/500
# 1324/1324 [==============================] - 85s 64ms/step - loss: 7.7678e-05 - mse: 7.7678e-05 - mape: 1.1103 - mae: 0.0068 - val_loss: 0.0015 - val_mse: 0.0015 - val_mape: 4.5833 - val_mae: 0.0273
# Epoch 227/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 7.9885e-05 - mse: 7.9885e-05 - mape: 1.1522 - mae: 0.0070 - val_loss: 0.0016 - val_mse: 0.0016 - val_mape: 4.6920 - val_mae: 0.0288
# Epoch 228/500
# ...
# Epoch 426/500
# 1324/1324 [==============================] - 84s 63ms/step - loss: 2.7608e-05 - mse: 2.7608e-05 - mape: 0.6707 - mae: 0.0040 - val_loss: 0.0015 - val_mse: 0.0015 - val_mape: 4.3640 - val_mae: 0.0261
# Epoch 427/500
# 1324/1324 [==============================] - 84s 63ms/step - loss: 2.8530e-05 - mse: 2.8530e-05 - mape: 0.6607 - mae: 0.0040 - val_loss: 0.0014 - val_mse: 0.0014 - val_mape: 4.3657 - val_mae: 0.0264
# Epoch 428/500
# 1324/1324 [==============================] - 84s 63ms/step - loss: 2.7303e-05 - mse: 2.7303e-05 - mape: 0.6644 - mae: 0.0040 - val_loss: 0.0014 - val_mse: 0.0014 - val_mape: 4.4028 - val_mae: 0.0266
# Epoch 429/500
# 1324/1324 [==============================] - 84s 63ms/step - loss: 2.7156e-05 - mse: 2.7156e-05 - mape: 0.6571 - mae: 0.0040 - val_loss: 0.0014 - val_mse: 0.0014 - val_mape: 4.4714 - val_mae: 0.0272
# Epoch 430/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.9762e-05 - mse: 2.9762e-05 - mape: 0.6747 - mae: 0.0040 - val_loss: 0.0014 - val_mse: 0.0014 - val_mape: 4.2484 - val_mae: 0.0257
# Epoch 431/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.6979e-05 - mse: 2.6979e-05 - mape: 0.6517 - mae: 0.0039 - val_loss: 0.0015 - val_mse: 0.0015 - val_mape: 4.6053 - val_mae: 0.0277
# Epoch 432/500
# 1324/1324 [==============================] - 84s 63ms/step - loss: 2.8564e-05 - mse: 2.8564e-05 - mape: 0.6720 - mae: 0.0040 - val_loss: 0.0014 - val_mse: 0.0014 - val_mape: 4.1617 - val_mae: 0.0249
# Epoch 433/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.4466e-05 - mse: 2.4466e-05 - mape: 0.6194 - mae: 0.0037 - val_loss: 0.0013 - val_mse: 0.0013 - val_mape: 4.1479 - val_mae: 0.0250
# Epoch 434/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.6821e-05 - mse: 2.6821e-05 - mape: 0.6601 - mae: 0.0040 - val_loss: 0.0013 - val_mse: 0.0013 - val_mape: 4.2357 - val_mae: 0.0253
# Epoch 435/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.7892e-05 - mse: 2.7892e-05 - mape: 0.6652 - mae: 0.0040 - val_loss: 0.0013 - val_mse: 0.0013 - val_mape: 4.3463 - val_mae: 0.0265
# Epoch 436/500
# 1324/1324 [==============================] - 84s 63ms/step - loss: 2.9395e-05 - mse: 2.9395e-05 - mape: 0.6905 - mae: 0.0041 - val_loss: 0.0013 - val_mse: 0.0013 - val_mape: 4.1935 - val_mae: 0.0251
# Epoch 437/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.9775e-05 - mse: 2.9775e-05 - mape: 0.6676 - mae: 0.0041 - val_loss: 0.0014 - val_mse: 0.0014 - val_mape: 4.3166 - val_mae: 0.0260
# Epoch 438/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.7985e-05 - mse: 2.7985e-05 - mape: 0.6557 - mae: 0.0040 - val_loss: 0.0015 - val_mse: 0.0015 - val_mape: 4.5414 - val_mae: 0.0275
# Epoch 439/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.7554e-05 - mse: 2.7554e-05 - mape: 0.6643 - mae: 0.0040 - val_loss: 0.0015 - val_mse: 0.0015 - val_mape: 4.6164 - val_mae: 0.0277
# Epoch 440/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.3906e-05 - mse: 2.3906e-05 - mape: 0.6276 - mae: 0.0038 - val_loss: 0.0016 - val_mse: 0.0016 - val_mape: 4.6683 - val_mae: 0.0284
# Epoch 441/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 3.1759e-05 - mse: 3.1759e-05 - mape: 0.6663 - mae: 0.0041 - val_loss: 0.0016 - val_mse: 0.0016 - val_mape: 4.7386 - val_mae: 0.0285
# Epoch 442/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 3.1905e-05 - mse: 3.1905e-05 - mape: 0.6841 - mae: 0.0041 - val_loss: 0.0014 - val_mse: 0.0014 - val_mape: 4.3480 - val_mae: 0.0262
# Epoch 443/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 3.0075e-05 - mse: 3.0075e-05 - mape: 0.6652 - mae: 0.0040 - val_loss: 0.0014 - val_mse: 0.0014 - val_mape: 4.3706 - val_mae: 0.0262
# Epoch 444/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.8581e-05 - mse: 2.8581e-05 - mape: 0.6668 - mae: 0.0040 - val_loss: 0.0013 - val_mse: 0.0013 - val_mape: 4.2231 - val_mae: 0.0252
# Epoch 445/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 3.2092e-05 - mse: 3.2092e-05 - mape: 0.6757 - mae: 0.0041 - val_loss: 0.0015 - val_mse: 0.0015 - val_mape: 4.5508 - val_mae: 0.0269
# Epoch 446/500
# 1324/1324 [==============================] - 84s 63ms/step - loss: 4.3643e-05 - mse: 4.3643e-05 - mape: 0.7127 - mae: 0.0043 - val_loss: 0.0015 - val_mse: 0.0015 - val_mape: 4.5581 - val_mae: 0.0275
# Epoch 447/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 3.1585e-05 - mse: 3.1585e-05 - mape: 0.6910 - mae: 0.0041 - val_loss: 0.0015 - val_mse: 0.0015 - val_mape: 4.5944 - val_mae: 0.0279
# Epoch 448/500
# 1324/1324 [==============================] - 84s 63ms/step - loss: 2.9586e-05 - mse: 2.9586e-05 - mape: 0.6814 - mae: 0.0041 - val_loss: 0.0015 - val_mse: 0.0015 - val_mape: 4.4556 - val_mae: 0.0272
# Epoch 449/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 3.1590e-05 - mse: 3.1590e-05 - mape: 0.6869 - mae: 0.0040 - val_loss: 0.0014 - val_mse: 0.0014 - val_mape: 4.4654 - val_mae: 0.0268
# Epoch 450/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.6997e-05 - mse: 2.6997e-05 - mape: 0.6492 - mae: 0.0039 - val_loss: 0.0015 - val_mse: 0.0015 - val_mape: 4.4746 - val_mae: 0.0272
# Epoch 451/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.7846e-05 - mse: 2.7846e-05 - mape: 0.6586 - mae: 0.0040 - val_loss: 0.0015 - val_mse: 0.0015 - val_mape: 4.3650 - val_mae: 0.0264
# Epoch 452/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.8338e-05 - mse: 2.8338e-05 - mape: 0.6694 - mae: 0.0040 - val_loss: 0.0014 - val_mse: 0.0014 - val_mape: 4.3218 - val_mae: 0.0262
# Epoch 453/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.6223e-05 - mse: 2.6223e-05 - mape: 0.6437 - mae: 0.0038 - val_loss: 0.0014 - val_mse: 0.0014 - val_mape: 4.2949 - val_mae: 0.0262
# Epoch 454/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.7036e-05 - mse: 2.7036e-05 - mape: 0.6548 - mae: 0.0040 - val_loss: 0.0013 - val_mse: 0.0013 - val_mape: 4.1418 - val_mae: 0.0248
# Epoch 455/500
# 1324/1324 [==============================] - 84s 63ms/step - loss: 2.6513e-05 - mse: 2.6513e-05 - mape: 0.6461 - mae: 0.0039 - val_loss: 0.0014 - val_mse: 0.0014 - val_mape: 4.4433 - val_mae: 0.0269
# Epoch 456/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.4867e-05 - mse: 2.4867e-05 - mape: 0.6303 - mae: 0.0038 - val_loss: 0.0014 - val_mse: 0.0014 - val_mape: 4.4417 - val_mae: 0.0272
# Epoch 457/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.4383e-05 - mse: 2.4383e-05 - mape: 0.6217 - mae: 0.0038 - val_loss: 0.0013 - val_mse: 0.0013 - val_mape: 4.1190 - val_mae: 0.0250
# Epoch 458/500
# 1324/1324 [==============================] - 84s 63ms/step - loss: 2.7905e-05 - mse: 2.7905e-05 - mape: 0.6406 - mae: 0.0039 - val_loss: 0.0017 - val_mse: 0.0017 - val_mape: 4.9227 - val_mae: 0.0304
# Epoch 459/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.7753e-05 - mse: 2.7753e-05 - mape: 0.6585 - mae: 0.0040 - val_loss: 0.0014 - val_mse: 0.0014 - val_mape: 4.3727 - val_mae: 0.0260
# Epoch 460/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.6033e-05 - mse: 2.6033e-05 - mape: 0.6534 - mae: 0.0039 - val_loss: 0.0016 - val_mse: 0.0016 - val_mape: 4.7051 - val_mae: 0.0288
# Epoch 461/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.8468e-05 - mse: 2.8468e-05 - mape: 0.6662 - mae: 0.0040 - val_loss: 0.0014 - val_mse: 0.0014 - val_mape: 4.4226 - val_mae: 0.0265
# Epoch 462/500
# 1324/1324 [==============================] - 84s 63ms/step - loss: 2.6155e-05 - mse: 2.6155e-05 - mape: 0.6384 - mae: 0.0039 - val_loss: 0.0013 - val_mse: 0.0013 - val_mape: 4.3306 - val_mae: 0.0259
# Epoch 463/500
# 1324/1324 [==============================] - 84s 63ms/step - loss: 2.7720e-05 - mse: 2.7720e-05 - mape: 0.6524 - mae: 0.0039 - val_loss: 0.0013 - val_mse: 0.0013 - val_mape: 4.2693 - val_mae: 0.0257
# Epoch 464/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.7994e-05 - mse: 2.7994e-05 - mape: 0.6477 - mae: 0.0039 - val_loss: 0.0014 - val_mse: 0.0014 - val_mape: 4.2766 - val_mae: 0.0256
# Epoch 465/500
# 1324/1324 [==============================] - 84s 63ms/step - loss: 2.8795e-05 - mse: 2.8795e-05 - mape: 0.6680 - mae: 0.0040 - val_loss: 0.0015 - val_mse: 0.0015 - val_mape: 4.6512 - val_mae: 0.0283
# Epoch 466/500
# 1324/1324 [==============================] - 84s 63ms/step - loss: 2.6981e-05 - mse: 2.6981e-05 - mape: 0.6436 - mae: 0.0039 - val_loss: 0.0014 - val_mse: 0.0014 - val_mape: 4.3157 - val_mae: 0.0260
# Epoch 467/500
# 1324/1324 [==============================] - 84s 63ms/step - loss: 2.3314e-05 - mse: 2.3314e-05 - mape: 0.6258 - mae: 0.0037 - val_loss: 0.0015 - val_mse: 0.0015 - val_mape: 4.4481 - val_mae: 0.0271
# Epoch 468/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.8210e-05 - mse: 2.8210e-05 - mape: 0.6686 - mae: 0.0040 - val_loss: 0.0013 - val_mse: 0.0013 - val_mape: 4.2095 - val_mae: 0.0253
# Epoch 469/500
# 1324/1324 [==============================] - 84s 63ms/step - loss: 2.6993e-05 - mse: 2.6993e-05 - mape: 0.6374 - mae: 0.0038 - val_loss: 0.0014 - val_mse: 0.0014 - val_mape: 4.3432 - val_mae: 0.0260
# Epoch 470/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.5744e-05 - mse: 2.5744e-05 - mape: 0.6328 - mae: 0.0038 - val_loss: 0.0014 - val_mse: 0.0014 - val_mape: 4.3045 - val_mae: 0.0260
# Epoch 471/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.9078e-05 - mse: 2.9078e-05 - mape: 0.6533 - mae: 0.0039 - val_loss: 0.0017 - val_mse: 0.0017 - val_mape: 4.8305 - val_mae: 0.0295
# Epoch 472/500
# 1324/1324 [==============================] - 84s 63ms/step - loss: 2.3810e-05 - mse: 2.3810e-05 - mape: 0.6135 - mae: 0.0037 - val_loss: 0.0015 - val_mse: 0.0015 - val_mape: 4.5267 - val_mae: 0.0276
# Epoch 473/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.5770e-05 - mse: 2.5770e-05 - mape: 0.6309 - mae: 0.0038 - val_loss: 0.0016 - val_mse: 0.0016 - val_mape: 4.5996 - val_mae: 0.0281
# Epoch 474/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.6854e-05 - mse: 2.6854e-05 - mape: 0.6352 - mae: 0.0038 - val_loss: 0.0014 - val_mse: 0.0014 - val_mape: 4.4224 - val_mae: 0.0264
# Epoch 475/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.4292e-05 - mse: 2.4292e-05 - mape: 0.6232 - mae: 0.0037 - val_loss: 0.0017 - val_mse: 0.0017 - val_mape: 4.8029 - val_mae: 0.0293
# Epoch 476/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.6285e-05 - mse: 2.6285e-05 - mape: 0.6404 - mae: 0.0038 - val_loss: 0.0014 - val_mse: 0.0014 - val_mape: 4.3153 - val_mae: 0.0256
# Epoch 477/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.4003e-05 - mse: 2.4003e-05 - mape: 0.6191 - mae: 0.0037 - val_loss: 0.0014 - val_mse: 0.0014 - val_mape: 4.4903 - val_mae: 0.0268
# Epoch 478/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.7642e-05 - mse: 2.7642e-05 - mape: 0.6613 - mae: 0.0040 - val_loss: 0.0015 - val_mse: 0.0015 - val_mape: 4.4060 - val_mae: 0.0265
# Epoch 479/500
# 1324/1324 [==============================] - 84s 63ms/step - loss: 2.5750e-05 - mse: 2.5750e-05 - mape: 0.6289 - mae: 0.0038 - val_loss: 0.0014 - val_mse: 0.0014 - val_mape: 4.2918 - val_mae: 0.0260
# Epoch 480/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.4880e-05 - mse: 2.4880e-05 - mape: 0.6150 - mae: 0.0037 - val_loss: 0.0014 - val_mse: 0.0014 - val_mape: 4.3999 - val_mae: 0.0263
# Epoch 481/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.4124e-05 - mse: 2.4124e-05 - mape: 0.6236 - mae: 0.0038 - val_loss: 0.0014 - val_mse: 0.0014 - val_mape: 4.4588 - val_mae: 0.0269
# Epoch 482/500
# 1324/1324 [==============================] - 84s 63ms/step - loss: 2.6017e-05 - mse: 2.6017e-05 - mape: 0.6368 - mae: 0.0038 - val_loss: 0.0014 - val_mse: 0.0014 - val_mape: 4.2543 - val_mae: 0.0260
# Epoch 483/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.5097e-05 - mse: 2.5097e-05 - mape: 0.6285 - mae: 0.0038 - val_loss: 0.0014 - val_mse: 0.0014 - val_mape: 4.4255 - val_mae: 0.0269
# Epoch 484/500
# 1324/1324 [==============================] - 84s 63ms/step - loss: 2.3535e-05 - mse: 2.3535e-05 - mape: 0.6106 - mae: 0.0037 - val_loss: 0.0014 - val_mse: 0.0014 - val_mape: 4.1605 - val_mae: 0.0251
# Epoch 485/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.9536e-05 - mse: 2.9536e-05 - mape: 0.6411 - mae: 0.0039 - val_loss: 0.0015 - val_mse: 0.0015 - val_mape: 4.5254 - val_mae: 0.0274
# Epoch 486/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.2720e-05 - mse: 2.2720e-05 - mape: 0.6082 - mae: 0.0037 - val_loss: 0.0014 - val_mse: 0.0014 - val_mape: 4.3312 - val_mae: 0.0261
# Epoch 487/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.6936e-05 - mse: 2.6936e-05 - mape: 0.6373 - mae: 0.0038 - val_loss: 0.0014 - val_mse: 0.0014 - val_mape: 4.3355 - val_mae: 0.0262
# Epoch 488/500
# 1324/1324 [==============================] - 84s 63ms/step - loss: 2.7323e-05 - mse: 2.7323e-05 - mape: 0.6438 - mae: 0.0039 - val_loss: 0.0014 - val_mse: 0.0014 - val_mape: 4.2940 - val_mae: 0.0260
# Epoch 489/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.4696e-05 - mse: 2.4696e-05 - mape: 0.6224 - mae: 0.0037 - val_loss: 0.0015 - val_mse: 0.0015 - val_mape: 4.4329 - val_mae: 0.0265
# Epoch 490/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.4126e-05 - mse: 2.4126e-05 - mape: 0.6145 - mae: 0.0037 - val_loss: 0.0014 - val_mse: 0.0014 - val_mape: 4.1963 - val_mae: 0.0253
# Epoch 491/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.6150e-05 - mse: 2.6150e-05 - mape: 0.6333 - mae: 0.0038 - val_loss: 0.0016 - val_mse: 0.0016 - val_mape: 4.6613 - val_mae: 0.0284
# Epoch 492/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.6186e-05 - mse: 2.6186e-05 - mape: 0.6385 - mae: 0.0039 - val_loss: 0.0014 - val_mse: 0.0014 - val_mape: 4.3750 - val_mae: 0.0260
# Epoch 493/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.6025e-05 - mse: 2.6025e-05 - mape: 0.6364 - mae: 0.0038 - val_loss: 0.0015 - val_mse: 0.0015 - val_mape: 4.5595 - val_mae: 0.0276
# Epoch 494/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.3039e-05 - mse: 2.3039e-05 - mape: 0.5950 - mae: 0.0036 - val_loss: 0.0014 - val_mse: 0.0014 - val_mape: 4.3175 - val_mae: 0.0260
# Epoch 495/500
# 1324/1324 [==============================] - 84s 63ms/step - loss: 2.2645e-05 - mse: 2.2645e-05 - mape: 0.6113 - mae: 0.0037 - val_loss: 0.0015 - val_mse: 0.0015 - val_mape: 4.3702 - val_mae: 0.0266
# Epoch 496/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.4924e-05 - mse: 2.4924e-05 - mape: 0.6330 - mae: 0.0038 - val_loss: 0.0013 - val_mse: 0.0013 - val_mape: 4.1932 - val_mae: 0.0251
# Epoch 497/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.3665e-05 - mse: 2.3665e-05 - mape: 0.6223 - mae: 0.0037 - val_loss: 0.0015 - val_mse: 0.0015 - val_mape: 4.4998 - val_mae: 0.0277
# Epoch 498/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.4106e-05 - mse: 2.4106e-05 - mape: 0.6206 - mae: 0.0037 - val_loss: 0.0013 - val_mse: 0.0013 - val_mape: 4.1511 - val_mae: 0.0250
# Epoch 499/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.4942e-05 - mse: 2.4942e-05 - mape: 0.6250 - mae: 0.0037 - val_loss: 0.0013 - val_mse: 0.0013 - val_mape: 4.1162 - val_mae: 0.0248
# Epoch 500/500
# 1324/1324 [==============================] - 84s 64ms/step - loss: 2.5497e-05 - mse: 2.5497e-05 - mape: 0.6412 - mae: 0.0038 - val_loss: 0.0014 - val_mse: 0.0014 - val_mape: 4.1981 - val_mae: 0.0254

# %%
#history = model.fit(X_train, y_train, validation_data = (X_val, y_val), epochs=300, batch_size =8)
# Plot training & validation accuracy values+
plt.plot(history.history['mse'])
plt.plot(history.history['val_mse'])
plt.ylim(ymin=-0, ymax=0.1)
plt.title('Mean squared error[MSE]')
plt.ylabel('Mse')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.savefig('MSE.png')
plt.show()

# Plot training & validation accuracy values
plt.plot(history.history['mape'])
plt.plot(history.history['val_mape'])
plt.title('Mean absolute percentage error[MAPE]')
plt.ylim(ymin=-0, ymax=10)
plt.ylabel('Mape')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.savefig('Mape.png')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['mae'])
plt.plot(history.history['val_mae'])
plt.ylim(ymin=-0, ymax=0.1)
plt.title('mae')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.savefig('mae.png')
plt.show()

# %%
preds = model.predict(X_test)
preds = preds *83.148

# %%
prediction = pd.DataFrame(preds, columns = ['prediction'])
prediction[('test')]=y_test*83.148
prediction[('diff')]=prediction[('test')]-prediction[('prediction')]
prediction.head()
# Out:
#    prediction    test      diff
# 0   60.436199  63.040  2.603801
# 1   56.802563  55.083 -1.719563
# 2   52.094635  49.443 -2.651635
# 3   53.561954  54.564  1.002046
# 4   53.426510  58.115  4.688490

# %%
prediction=prediction.sort_values(by=['test'])
prediction = prediction.reset_index()
prediction.head()
# Out:
#    index  prediction    test      diff
# 0    124   32.509911  30.137 -2.372911
# 1     83   37.833508  30.721 -7.112508
# 2    159   36.153725  31.081 -5.072725
# 3     62   36.620411  31.605 -5.015411
# 4      9   34.455238  32.506 -1.949238

# %%
mu = prediction["diff"].mean()
sigma = prediction["diff"].std()
s = prediction["diff"]
count, bins, ignored = plt.hist(s, 30, density=True)
plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) * np.exp( - (bins - mu)**2 / (2 * sigma**2) ), linewidth=2, color='r')
plt.rcParams["figure.figsize"] = (10, 5)
plt.title("Distribution of error")
plt.savefig('error_dist.png')
plt.show()

# %%
prediction.describe()
# Out:
#             index  prediction        test        diff
# count  166.000000  166.000000  166.000000  166.000000
# mean    82.500000   51.415028   51.075030   -0.340000
# std     48.064193    6.460808    7.169302    2.416704
# min      0.000000   32.509911   30.137000   -7.573602
# 25%     41.250000   50.261264   49.451250   -1.946432
# 50%     82.500000   52.024448   51.789500   -0.235958
# 75%    123.750000   53.692282   54.548000    1.191629
# max    165.000000   76.518364   76.115000    5.482297

# %%
coeff_regr = r2_score(prediction[("test")], prediction[("prediction")])
print(coeff_regr)
# Out:
# 0.88410728742628

# %%
plt.rcParams['figure.figsize'] = (16, 8)
# GG-Plot version
data1 = prediction[('prediction')]
data2 = prediction[('test')]
#data3 = prediction[('diff')]



fig, ax1 = plt.subplots()
plt.rcParams.update({'font.size': 23})
ax1.set_xlabel('Sensor ID')
ax1.set_ylabel('Thickness[um]')
ax1.plot(data1, color='green', label='Predicted value', linewidth=2)
ax1.plot(data2, color='blue', label='Actual value', linewidth=2)
#ax1.plot(data3, color='red', label='Difference', linewidth=2)


#ax1.set_xlim(left=0, right=2.5, emit=True, auto=False)
ax1.set_ylim(bottom=20, top=85)
#ax1.xaxis.set_major_formatter(x_formatter)
#ax1.xaxis.set_major_locator(x_locator)
ax1.legend()
plt.savefig('thickness_resnet60nofc3.png')
plt.title('Prediction of thickness_VGG16_nofc')
fig.tight_layout() 

plt.show()

# %%
#save model
save = True
if save == True:
    model_json = model.to_json()
    with open("model_json", "w") as json_file:
        json_file.write(model_json)
    model.save_weights("model_rednet50_nofc3.h5")
    print("model is saved")
# Out:
# model is saved
